# %%
import numpy as np
import collections
from datetime import datetime

from scipy.stats import pearsonr
from scipy.stats import spearmanr
from sklearn.metrics.pairwise import cosine_similarity
from scipy import spatial
from scipy import stats

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.nn.functional as F
torch.manual_seed(1)
import torch.distributions as distb


import time
import datetime

from collections import defaultdict
from collections import Counter

from random import randint
import pickle

# %%
class BayesianSG(nn.Module):
    def __init__(self, vocab_size, embedding_size):
        super(BayesianSG, self).__init__()

        self.w_embeddings = nn.Embedding(vocab_size, embedding_size)
        self.dense_weights = nn.Linear(embedding_size*2, embedding_size)
        self.muLinear = nn.Linear(embedding_size, embedding_size)
        self.sigmaLinear = nn.Linear(embedding_size, embedding_size)

        self.Location = nn.Embedding(vocab_size, embedding_size)
        self.Scale = nn.Embedding(vocab_size, embedding_size)
        self.fLinear = nn.Linear(embedding_size, vocab_size)

        self.std_mean = torch.zeros(embedding_size)
        self.std_cov = torch.diag(torch.ones(embedding_size))

     

    def forward(self, center_words, context_words):
    
        context_words = context_words.view(1, -1)
        context_size = context_words.size(1)

        # Inference model
        x_stacked = center_words.repeat(context_size, 1).transpose(0, 1)
        center_embedding = self.w_embeddings(x_stacked)
        context_embedding = self.w_embeddings(context_words)
        out = self.dense_weights(torch.cat([center_embedding, context_embedding], -1))
        emb = F.relu(out)
        emb_sum = emb.sum(1)

        mu_posterior = self.muLinear(emb_sum)
        sigma_posterior = F.softplus(self.sigmaLinear(emb_sum))

        dims = mu_posterior.shape
        #epsilon = torch.distributions.multivariate_normal.MultivariateNormal \
        #(torch.zeros(dims),torch.diag(torch.ones(dims)))
       
   
     
  
        epsilon = distb.MultivariateNormal(self.std_mean, self.std_cov)
        epsilon = epsilon.sample()

        z = mu_posterior +  epsilon * sigma_posterior


        logprobs = F.log_softmax(self.fLinear(z), dim=-1).squeeze(0)

        mu = self.Location(center_words)
        sigma = F.softplus(self.Scale(center_words))

        loss_probs = torch.zeros_like(context_words).type(torch.FloatTensor)
 
        sum_loss = 
        for i, context_word in enumerate(context_words):
            loss_probs[i] = logprobs[context_word]

        neg_loss = loss_probs.sum(-1)
        loss1 = torch.log(sigma/sigma_posterior)
        numerator = (sigma_posterior.pow(2) + (mu_posterior - sigma).pow(2))
        total_loss = (loss1 + numerator / (2*sigma.pow(2)) - 0.5).sum()


        final_loss = (total_loss - neg_loss).mean()
        return final_loss

# %%
import string

def stop_words(file_name, punctuation=True):
    with open(file_name) as f:
        stop_word_list = [line.strip() for line in f.readlines()]
    
    for p in list(string.punctuation):
        stop_word_list.append(p)
    
    return stop_word_list

stop_word_list = stop_words("data/en_stopwords.txt")

# %%
def sentences_reader(dataset_path, stop_word_list):
    sentence_list = []
    with open(dataset_path) as f:
        for line in f:
            line = line.split()
            line = [word.lower() for word in line]
            line = [word for word in line if word not in stop_word_list]
            sentence_list.append(line)
    
    return sentence_list

sentences = sentences_reader("data/wa/dev.en", stop_word_list )

# %%
from collections import defaultdict


def UnigramTable(sentences, max_size):
    table = {}
    frequency = collections.defaultdict(int)
    n = 0
    
    
    for sentence in sentences:
        for word in sentence:
            table[n] = word
            frequency[word] += 1
            n+= 1
    
    return table, frequency

# %%
def vocabulary_creation(sentences, max_size = 10000):
    special_tokens = {"$UNK$", "$EOS$", "$SOS$", "$PAD"}
    index  = {}

    sentence_count = len(sentences)

    table, frequency = UnigramTable(sentences, max_size)
    
    num_tokens =  sum(frequency.values())

    counts = list(frequency.items())
    
    counts.sort(key=lambda _: -_[1])
    
    most_freq = [w[0] for w in counts[: max_size - len(special_tokens)]]


    index = dict([ (w, i) for i, w in enumerate(most_freq)])
    
    for special_token in special_tokens:
        assert special_token not in index
        index[special_token] = len(index)

    inverse_index = dict([(v, k) for (k, v) in index.items()])

    N = len(index)
    
    return index, inverse_index, N

index, inverse_index, N = vocabulary_creation(sentences, max_size = 10000)
        

def one_hot_vector(word, index, N):
    if word not in index:
        word = "$UNK$"
    vector = np.zeros(N)
    vector[index[word]] = 1
    
    return vector
    
def unknown_check(sentence, index):
    output = []
    for word in sentence:
        if word not in index:
            word = "$UNK$"
        output.append(word)
    return output
    

def retrieve_contexts(sentence, index, context_window):
    n_ = context_window // 2
    context = set()
    for i in range(index - n_, index + n_ + 1):
        if i == index or i < 0 or i >= len(sentence):
            continue
        context.add(sentence[i])
    return context

# %%
embedding_dim = 100
vocab_size = 10000
window_size = 5
epochs = 10
dataset_path = "data/wa/dev.en"
model_name = "bayesian_skipgram"

sentences = sentences_reader(dataset_path, stop_word_list)

index, inverse_index, N = vocabulary_creation(sentences, max_size = vocab_size)


bsm = BayesianSG(N, embedding_dim)

optimizer = optim.Adam(bsm.parameters(), lr=1e-4)

epoch_losses = []
for epoch in range(1, epochs + 1):
    print("Running epoch: ", epoch)
    then = time.time()

    epoch_loss = 0
    count = 0
    for sentence_num, sentence in enumerate(sentences):            
        for center_idx, center_word in enumerate(sentence):
            if center_word not in index:
                continue
            center_vec = one_hot_vector(center_word, index, N)
            context_words = []
            context_idx = []
            for word in retrieve_contexts(unknown_check(sentence, index), center_idx, window_size):
                if word not in index:
                    continue
                context_idx.append(index[word])
                context_words.append(one_hot_vector(word, index, N))
            if len(context_words) == 0:
                continue
            optimizer.zero_grad()
            loss = bsm(torch.LongTensor(np.array([index[center_word]])), torch.LongTensor(context_idx))
         
            epoch_loss = epoch_loss + loss.item()
            count = count+1

            loss.backward()
            optimizer.step()
    
    now = time.time()
    epoch_loss_avg = epoch_loss / count
    epoch_losses.append(epoch_loss_avg)
    print("average loss: ", epoch_loss_avg, "time: ",now-then)

#TODO save model
# Out:
# Running epoch:  1
# average loss:  397.7042032006669 time:  1.8488249778747559
# Running epoch:  2
# average loss:  261.43158559929833 time:  1.1740000247955322
# Running epoch:  3
# average loss:  207.5242339095024 time:  1.139603853225708
# Running epoch:  4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-d194d8aced5f> in <module>()
#      42             count = count+1
#      43
# ---> 44             loss.backward()
#      45             optimizer.step()
#      46
#
# /Users/basaktugceeskili/anaconda/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# /Users/basaktugceeskili/anaconda/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
def get_embeddings(model):
    
    return model.w_embeddings.weight.data, model.lin1.weight.data

def save_embeddings(embeds, file_name):
    
    with open(file_name, 'wb') as file:
        pickle.dump(embeds.numpy(), file)

# %%
wm, cm = get_embeddings(model)
save_embeddings(wm, 'wordvecs_bayesian_skipgram.pickle')

# %%
#### Evaluation Reading #####

class Sentence:
    def __init__(self, target,complete,sent_id,position,tokens):
        self.target = target
        self.complete = complete
        self.sent_id = sent_id
        self.position = position
        self.tokens = tokens

        
        
with open('data/lst/lst_test.preprocessed', 'r') as myfile:
    data = myfile.readlines()

    
sentence_list = []
    
for line in data:
    line = line.split()
    target = line[0].split(".")[0]
    complete = line[0]
    sent_id = line[1]
    position = line[2]
    tokens = line[3:]
    sent_example = Sentence(target,complete,sent_id,position,tokens)
    
    sentence_list.append(sent_example)

# %%
with open('data/lst/lst.gold.candidates', 'r') as myfile:
    data = myfile.readlines()

    
word_candidates = {}
    
for line in data:
    
    word = line.split(":")[0][:-2]
    #print(word[:-2])
    candidates = line[:-1].split(":")[2].split(";")
    #print(candidates)
    
    word_candidates[word] = candidates

# %%
word_candidates
# Out:
# {'about': ['here and there',
#   'regarding',
#   'around',
#   'of',
#   'concerning',
#   'arise',
#   'discussed',
#   'dealing with',
#   'approximately',
#   'roughly',
#   'cope with',
#   'nearly',
#   'somewhat',
#   'more or less',
#   'occur',
#   'happen',
#   'consider',
#   'round',
#   'concerned with'],
#  'account': ['access',
#   'balance',
#   'description',
#   'chronicle',
#   'facility',
#   'bank balance',
#   'explanation',
#   'ledger',
#   'finance',
#   'banking facility',
#   'subscriber',
#   'fund',
#   'synopsis',
#   'asset',
#   'statement',
#   'narrative',
#   'report',
#   'consideration',
#   'subscription',
#   'logon',
#   'banking arrangement'],
#  'acquire': ['amass',
#   'purchase',
#   'buy',
#   'secure',
#   'get',
#   'receive',
#   'gather',
#   'procure',
#   'obtain',
#   'collect',
#   'bring in',
#   'gain',
#   'learn',
#   'find',
#   'achieve'],
#  'acute': ['heightened',
#   'emergency',
#   'sensitive',
#   'sudden',
#   'urgent',
#   'severe',
#   'critical',
#   'serious',
#   'sharp',
#   'keen',
#   'pn',
#   'intense',
#   'grave'],
#  'apparently': ['supposedly',
#   'clearly',
#   'plainly',
#   'ostensibly',
#   'seemingly',
#   'obviously',
#   'looking',
#   'it seems',
#   'manifestly',
#   'evidently',
#   'palpably'],
#  'around': ['living',
#   'about',
#   'approximately',
#   'all over',
#   'over',
#   'there',
#   'roughly',
#   'alive',
#   'back on itself',
#   'here',
#   'surrounding',
#   'everywhere',
#   'in the vicinity',
#   'encircling',
#   'through out the world',
#   'here and there',
#   'round',
#   'close to'],
#  'away': ['gone',
#   'depart',
#   'head off',
#   'seizing',
#   'distant',
#   'stealing',
#   'go',
#   'with impunity',
#   'out',
#   'leave',
#   'removing',
#   'aside',
#   'confiscate',
#   'elsewhere',
#   'distance',
#   'distancing themselves',
#   'repeatedly',
#   'along',
#   'in the future',
#   'rebuff',
#   'apart',
#   'absent',
#   'off',
#   'ahead',
#   'hence',
#   'and removing it',
#   'repel',
#   'continuously',
#   'afar'],
#  'bar': ['obstruct',
#   'restriction',
#   'prevent',
#   'rod',
#   'obstruction',
#   'pole',
#   'hurdle',
#   'marker',
#   'exclude',
#   'slab',
#   'indicator',
#   'snack',
#   'exclusion',
#   'apparatus',
#   'menu',
#   'lounge',
#   'crossbar',
#   'barrier',
#   'drinking house',
#   'pub',
#   'prohibition',
#   'handlebar',
#   'hostelry',
#   'banner',
#   'level',
#   'biscuit',
#   'metal',
#   'ban',
#   'saloon',
#   'block',
#   'drinking lounge'],
#  'below': ['lower down',
#   'later',
#   'attached',
#   'underneath',
#   'included',
#   'following',
#   'beneath'],
#  'blow': ['criticism',
#   'knock',
#   'hit',
#   'reverse',
#   'shock',
#   'punch',
#   'clout',
#   'air',
#   'hair',
#   'thrust',
#   'attack',
#   'setback',
#   'hot air',
#   'thump',
#   'strike',
#   'knockback',
#   'movement',
#   'rebuff',
#   'wind',
#   'disaster'],
#  'blue': ['melancholy',
#   'naughty',
#   'pornographic',
#   'depressed',
#   'speculative',
#   'purple',
#   'grey',
#   'unhappy',
#   'sad',
#   'down',
#   'pale grey',
#   'cobalt',
#   'indecent',
#   'sapphire',
#   'azure',
#   'conservative',
#   'pn',
#   'shady'],
#  'board': ['wipeboard',
#   'directorate',
#   'motherboard',
#   'executive',
#   'site',
#   'committee',
#   'table',
#   'management',
#   'group',
#   'organisation',
#   'administration',
#   'playing surface',
#   'blackboard',
#   'screen',
#   'game',
#   'card',
#   'panel',
#   'forum',
#   'whiteboard',
#   'message area',
#   'governing body',
#   'display'],
#  'bright': ['alight',
#   'skilled',
#   'deep',
#   'good',
#   'sharp',
#   'luminous',
#   'colourful',
#   'optimisitc',
#   'vivid',
#   'capable',
#   'positive',
#   'hopeful',
#   'shining',
#   'intelligent',
#   'smart',
#   'clever',
#   'motivated',
#   'vibrant',
#   'up-and-coming',
#   'well-lit',
#   'gleam',
#   'most talented',
#   'great',
#   'talented',
#   'most able',
#   'brilliant',
#   'light',
#   'clear',
#   'gifted',
#   'promising'],
#  'bring': ['topple',
#   'incorporate',
#   'force',
#   'convey',
#   'move',
#   'ruin',
#   'file',
#   'carry',
#   'return',
#   'bore',
#   'create',
#   'attract',
#   'transport',
#   'depress',
#   'make',
#   'start',
#   'call',
#   'take',
#   'instigate',
#   'draw',
#   'restore to',
#   'make more like',
#   'get',
#   'deliver',
#   'introduce',
#   'produce',
#   'put',
#   'generate',
#   'present',
#   'contribute',
#   'shoot',
#   'institute',
#   'gather',
#   'initiate',
#   'realise',
#   'make more similar',
#   'guide'],
#  'bug': ['insect',
#   'gremlin',
#   'obsession',
#   'fever',
#   'tap',
#   'become obsessed with',
#   'coding error',
#   'fault',
#   'defect',
#   'infection',
#   'surveillance',
#   'virus',
#   'error',
#   'surveillance device',
#   'code defect',
#   'problem',
#   'germ',
#   'addiction',
#   'spying device',
#   'craze',
#   'listening device'],
#  'bull': ['bulls eye',
#   'suitor',
#   'nonsense',
#   'powerful male',
#   'adult male cow',
#   'rising',
#   'adult male',
#   'booming',
#   'crap',
#   'male cow',
#   'stud',
#   'animal',
#   'grasped the nettle',
#   'document',
#   'warrant',
#   'edict',
#   'act decisively',
#   'centre',
#   'be accurate',
#   'growing',
#   'male bovine',
#   'rubbish',
#   'load of rubbish',
#   'target',
#   'cow',
#   'stag',
#   'bovine animal',
#   'centre circle',
#   'fearlessly tackled the problem',
#   'male'],
#  'burst': ['explode on',
#   'bound',
#   'pop',
#   'erupt on to',
#   'end',
#   'laden',
#   'rupture',
#   'erupt with laughter',
#   'leap',
#   'descend',
#   'bristle',
#   'surprise',
#   'split',
#   'run',
#   'fracture',
#   'deflate',
#   'break',
#   'bounce',
#   'barge',
#   'full to burst',
#   'arrive on',
#   'overflow',
#   'explode on to',
#   'erupt on',
#   'rush',
#   'enthusiastic',
#   'cover',
#   'explode',
#   'erupt',
#   'burgeon',
#   'push'],
#  'call': ['dial',
#   'entitle',
#   'name',
#   'refer to as',
#   'dub',
#   'describe',
#   'request',
#   'telephone',
#   'label',
#   'phone',
#   'contact',
#   'term',
#   'describe as',
#   'address',
#   'ring',
#   'summon',
#   'know as',
#   'refer to',
#   'designate'],
#  'can': ['bin', 'container', 'disposal', 'cannister', 'tin', 'receptacle'],
#  'cap': ['lid',
#   'restriction',
#   'ceiling',
#   'limited tax',
#   'hat',
#   'nozzle',
#   'tip',
#   'limit',
#   'capital',
#   'pileus',
#   'pn',
#   'top',
#   'headdress'],
#  'caravan': ['house trailer',
#   'trailer ',
#   'convoy',
#   'cavalcade',
#   'camping',
#   'traveller',
#   'roadshow',
#   'company',
#   'camper',
#   'convey',
#   'mobile home',
#   'band',
#   'train',
#   'camp trailer',
#   'party',
#   'vehicle',
#   'group',
#   'crocodile',
#   'trailer',
#   'troop'],
#  'carry': ['fulfil',
#   'convey',
#   'conclude',
#   'bring',
#   'undertake',
#   'transport',
#   'use',
#   'accomplish',
#   'perform',
#   'send',
#   'take',
#   'lug',
#   'transmit',
#   'do',
#   'complete',
#   'deploy',
#   'bear',
#   'drag',
#   'be fitted with',
#   'hold',
#   'execute',
#   'clutch',
#   'have on them',
#   'contain',
#   'pack'],
#  'change': ['evolve',
#   'amend',
#   'shift',
#   'move',
#   'modify',
#   'transform',
#   'update',
#   'switch',
#   'adjust',
#   'become different',
#   'alter',
#   'vary'],
#  'charge': ['control',
#   'criticism',
#   'prosecution',
#   'expense',
#   'power',
#   'offence',
#   'fee',
#   'authority',
#   'accusation',
#   'cost',
#   'command',
#   'allegation',
#   'tariff',
#   'indictment',
#   'issue',
#   'payment'],
#  'check': ['report',
#   'examine',
#   'hand in',
#   'select',
#   'make sure',
#   'confirm',
#   'verify',
#   'admit',
#   'submit',
#   'mark',
#   'note',
#   'test',
#   'look at',
#   'inspect',
#   'scrutinise',
#   'put',
#   'tick',
#   'take notice',
#   'search',
#   'register',
#   'investigate',
#   'survey'],
#  'civil': ['cordial',
#   'civic',
#   'nongovernmental',
#   'community',
#   'general',
#   'elected',
#   'thoughtful',
#   'individual',
#   'well mannered',
#   'personal',
#   'ordinary private',
#   'cultured',
#   'public',
#   'state',
#   'internal',
#   'citizen',
#   'ordinary',
#   'friendly',
#   "citizens'",
#   'domestic',
#   'polite',
#   'private',
#   "people's",
#   'benevolent',
#   'noncriminal',
#   'inoffensive',
#   'social',
#   'courteous'],
#  'clean': ['restore',
#   'rectify',
#   'win',
#   'tidy',
#   'profit greatly',
#   'wash up',
#   'wash',
#   'tidy up',
#   'fix',
#   'scrape',
#   'repair',
#   'mend',
#   'correct',
#   'empty',
#   'prosper',
#   'finish',
#   'complete',
#   'freshen up',
#   'disinfect',
#   'accumulate',
#   'cleanse',
#   'wipe',
#   'spruce up',
#   'clear',
#   'purify',
#   'remedy',
#   'remove',
#   'purge',
#   'make a fortune'],
#  'clear': ['dealt with',
#   'take away',
#   'pardon',
#   'process',
#   'get rid of',
#   'move',
#   'tidy',
#   'absolve',
#   'unblock',
#   'skim',
#   'pass',
#   'move away',
#   'be freed',
#   'acquit',
#   'exonerate',
#   'authorise',
#   'brighten',
#   'be authorised',
#   'eliminate',
#   'above',
#   'over',
#   'empty',
#   'take',
#   'sort',
#   'vindicate',
#   'free',
#   'open up',
#   'cut down',
#   'change',
#   'improve',
#   'get above',
#   'cash',
#   'remove',
#   'unobstruct',
#   'release'],
#  'close': ['about',
#   'near ',
#   'almost',
#   'contiguous',
#   'next',
#   'near',
#   'neighbouring',
#   'adjacent',
#   'local',
#   'proximate'],
#  'closely': ['strongly',
#   'narrowly',
#   'alongside',
#   'together',
#   'neatly',
#   'in unison',
#   'in detail',
#   'jointly',
#   'intimately',
#   'collectively',
#   'nearly',
#   'directly',
#   'carefully',
#   'in concert',
#   'scrupulously',
#   'in tandem',
#   'attentively',
#   'approximately',
#   'intently'],
#  'coach': ['trainer',
#   'travel bus',
#   'bus',
#   'counsellor',
#   'tutor',
#   'carriage',
#   'car',
#   'instructor',
#   'teacher',
#   'transport'],
#  'come': ['originate',
#   'proposed by',
#   'spring to mind',
#   'spring',
#   'notice',
#   'arrive ',
#   'occur to one',
#   'rally',
#   'happen',
#   'enter my',
#   'occur',
#   'concern',
#   'considering',
#   'be connected with',
#   'appear',
#   'chance upon',
#   'unite',
#   'find',
#   'fall off',
#   'combine',
#   'take place',
#   'return',
#   'get',
#   'reach',
#   'arrive at',
#   'fall',
#   'report',
#   'encounter',
#   'be about',
#   'join',
#   'we consider',
#   'gather',
#   'be not organised',
#   'turn up',
#   'leave',
#   'emanate ',
#   'lever',
#   'arrive'],
#  'cross': ['sample',
#   'mixture',
#   'sequence',
#   'hybrid',
#   'angry',
#   'annoyed',
#   'two intersecting lines',
#   'mixture of',
#   'irate',
#   'transverse',
#   'hybrid of',
#   'typical sample',
#   'crucifix',
#   'representative sample',
#   'x shape',
#   'x',
#   'segment',
#   'right angled cut',
#   'irritated'],
#  'cry': ['exclaim',
#   'sob',
#   'wail',
#   'tear',
#   'bawl',
#   'shout',
#   'snivel',
#   'call',
#   'demand',
#   'utter',
#   'yell',
#   'weep',
#   'shriek',
#   'complain'],
#  'dark': ['unclear',
#   'obscure situation',
#   'oblivious',
#   'lack of light',
#   'darkness',
#   'somewhere unilluminated',
#   'dusk',
#   'absence of light',
#   'secret',
#   'black',
#   'unsure',
#   'uninformed',
#   'ignorance',
#   'ignorant',
#   'at night',
#   'nightfall',
#   'shadow',
#   'ininformed',
#   'mystery',
#   'gloom',
#   'uncertain',
#   'unilluminated',
#   'away from light',
#   'oblivion',
#   'sunset',
#   'sombre',
#   'shade',
#   'night',
#   'dimness',
#   'unaware'],
#  'decline': ['refuse',
#   'forgo ',
#   'get worse',
#   'reduce',
#   'reject',
#   'lessen',
#   'decrease',
#   'fall',
#   'drop',
#   'deteriorate',
#   'weaken'],
#  'dismiss': ['dispatch',
#   'fire',
#   'send away',
#   'reject',
#   'let out',
#   'remove',
#   'sack',
#   'ignore',
#   'excuse',
#   'see',
#   'deride',
#   'lay off',
#   'discard',
#   'release',
#   'discharge',
#   'banish'],
#  'draw': ['claim',
#   'sketch',
#   'set',
#   'consider',
#   'obtain',
#   'bring',
#   'exploit',
#   'lead to',
#   'extract',
#   'select',
#   'portray',
#   'use',
#   'depict',
#   'attract',
#   'make',
#   'schedule',
#   'paint',
#   'call',
#   'take',
#   'tie',
#   'rely',
#   'choose',
#   'make use of',
#   'play',
#   'get',
#   'pit',
#   'acquire',
#   'take from',
#   'focus',
#   'drag',
#   'derive',
#   'consult',
#   'pull',
#   'earn',
#   'receive',
#   'gather',
#   'haul',
#   'remove',
#   'summon',
#   'employ',
#   'withdraw'],
#  'drop': ['dump',
#   'deliver ',
#   'terminate',
#   'let go of',
#   'discontinue',
#   'ditch',
#   'send a letter',
#   'let fall',
#   'pause',
#   'deselect',
#   'send',
#   'put down',
#   'write',
#   'text',
#   'set down',
#   'email',
#   'relinquish',
#   'decline',
#   'stop',
#   'deliver',
#   'release',
#   'write a letter',
#   'fall',
#   'left round',
#   'throw',
#   'send a message',
#   'lower',
#   'unload',
#   'omit',
#   'leave',
#   'leave out',
#   'abandon',
#   'weigh'],
#  'dry': ['tongue in cheek',
#   'waterless',
#   'become empty',
#   'unmoistened',
#   'run out',
#   'out',
#   'impassive',
#   'deadpan',
#   'arid',
#   'desiccated',
#   'understated',
#   'empty',
#   'wry',
#   'flat',
#   'soulless',
#   'teetotal',
#   'rainless',
#   'facetious',
#   'unsympathetic',
#   'evaporate',
#   'low key',
#   'alcohol free',
#   'drought',
#   'dull',
#   'stodgy',
#   'boring',
#   'droll',
#   'parched',
#   'uninteresting'],
#  'earlier': ['in previous times',
#   'formerly',
#   'previously',
#   'in advance of',
#   'beforehand',
#   'sooner',
#   'prior to that',
#   'initially',
#   'ahead of',
#   'sooner than',
#   'by then',
#   'before this',
#   'in advance',
#   'before'],
#  'easy': ['accessible',
#   'undemanding',
#   'more accessible',
#   'straightforward',
#   'less',
#   'simple',
#   'convenient',
#   'carefree',
#   'more straightforward',
#   'possible',
#   'not difficult',
#   'less difficult',
#   'trouble free',
#   'uncomplicated',
#   'common'],
#  'education': ['training',
#   'educated',
#   'knowledge',
#   'college',
#   'study',
#   'instruction',
#   'schooling',
#   'tuition',
#   'place',
#   'learning',
#   'bringing up',
#   'teaching',
#   'erudition',
#   'intellect'],
#  'endure': ['undergo',
#   'last',
#   'tolerate',
#   'go through',
#   'bear',
#   'put up with',
#   'submit to',
#   'continue',
#   'experience',
#   'have',
#   'persist',
#   'suffer'],
#  'entirely': ['fully',
#   'exclusively',
#   'wholly',
#   'completely',
#   'utterly',
#   'altogether',
#   'continuously',
#   'totally'],
#  'examination': ['exam',
#   'enquiry',
#   'assessment',
#   'study',
#   'analysis',
#   'scrutiny',
#   'consultation',
#   'investigation',
#   'assesment',
#   'test',
#   'inspection'],
#  'execution': ['the chair',
#   'the death penalty',
#   'completion',
#   'death',
#   'implementation',
#   'administration',
#   'putting to death',
#   'application',
#   'production',
#   'actualisation',
#   'performance',
#   'carrying out',
#   'method',
#   'enforcement',
#   'fulfilment',
#   'killing',
#   'running',
#   'operation ',
#   'discharge',
#   'transaction',
#   'capital punishment',
#   'death sentence'],
#  'extended': ['wide',
#   'lengthy',
#   'additional',
#   'broad',
#   'expanded',
#   'protracted',
#   'prolonged',
#   'long',
#   'lengthened',
#   'enlarged',
#   'comprehensive',
#   'expansive',
#   'drawn out',
#   'extensive',
#   'augmented',
#   'elongated',
#   'increased'],
#  'external': ['outer',
#   'nonlocal',
#   'foreign',
#   'outside',
#   'link',
#   'exterior',
#   'outward'],
#  'fall': ['be unsuccessful',
#   'do not meet',
#   'do not come up to',
#   'tumble',
#   'fail to meet',
#   'drop',
#   'come down',
#   'doze off',
#   'land',
#   'drop off',
#   'take',
#   'slip',
#   'disappoint',
#   'fail',
#   'become',
#   'plunge',
#   'go to sleep',
#   'come',
#   'undershoot',
#   'be taken',
#   'descend'],
#  'fear': ['dread entering',
#   'scared of',
#   'be frightened',
#   'be concerned',
#   'expect',
#   'worry',
#   'be alarmed by',
#   'be frightened of',
#   'be alarmed',
#   'suspect',
#   'be scared of',
#   'be anxious',
#   'be afraid',
#   'be sorry',
#   'be worried',
#   'believe',
#   'be frightened by',
#   'anxiously anticipated',
#   'unfortunately',
#   'afraid of',
#   'anticipate',
#   'be afraid of',
#   'frightened of',
#   'dread',
#   'be apprehensive',
#   'worry about',
#   'scare'],
#  'field': ['domain',
#   'speciality',
#   'community',
#   'sphere',
#   'investigative',
#   'pitch',
#   'battleground',
#   'ground',
#   'discipline',
#   'area of operation',
#   'area',
#   'section',
#   'environment',
#   'geographical',
#   'subject',
#   'province',
#   'field of vision',
#   'acreage',
#   'licence',
#   'on the streets',
#   'holder',
#   'box',
#   'land',
#   'resource',
#   'region',
#   'data item',
#   'activity'],
#  'figure': ['people',
#   'calculation',
#   'image',
#   'number',
#   'entity',
#   'individual',
#   'statistic',
#   'total',
#   'person of authority',
#   'organisation',
#   'character',
#   'personage',
#   'numeral',
#   'leader',
#   'picture',
#   'illustration',
#   'diagram',
#   'representative',
#   'data',
#   'account',
#   'value',
#   'person',
#   'amount'],
#  'film': ['movie', 'production', 'documentary', 'picture'],
#  'finally': ['eventually',
#   'ultimately',
#   'to conclude',
#   'in conclusion',
#   'also',
#   'at last',
#   'at long last',
#   'last of all',
#   'lastly'],
#  'find': ['consider',
#   'show',
#   'feel',
#   'discover',
#   'invent',
#   'see',
#   'exist',
#   'determine',
#   'seek',
#   'detect',
#   'calculate',
#   'write',
#   'recognised as',
#   'locate',
#   'buy',
#   'get',
#   'felt',
#   'obtain',
#   'believe',
#   'look for',
#   'present',
#   'evident',
#   'realise is',
#   'see as',
#   'ascertail',
#   'realise',
#   'perceive as',
#   'think'],
#  'fire': ['shoot',
#   'launch',
#   'dismiss',
#   'sack',
#   'lay off',
#   'shoot at',
#   'discharge'],
#  'fix': ['sort out',
#   'repair',
#   'resolve',
#   'set',
#   'do',
#   'heal',
#   'make up for',
#   'compensate for',
#   'cure',
#   'solve',
#   'stick',
#   'determine',
#   'mend',
#   'put right',
#   'patch',
#   'intent',
#   'correct',
#   'improve'],
#  'flat': ['invariable rate',
#   'even surface',
#   'gently',
#   'fixed rate',
#   'flush',
#   'total',
#   'absolute',
#   'even',
#   'uniform',
#   'categoric',
#   'shallow',
#   'plane',
#   'horizontal',
#   'downright',
#   'outright',
#   'level',
#   'plain',
#   'straight',
#   'smooth',
#   'lifeless',
#   'thin',
#   'deflated',
#   'fixed'],
#  'forget': ['fail to remember',
#   'ignore',
#   'omit',
#   'remember',
#   'put out of mind',
#   'overlook',
#   'not remember',
#   'inadvertently omit',
#   'fail',
#   'omit to remember',
#   'cease to remember',
#   'lose',
#   'disregard',
#   'cease to be remembered',
#   'let slip',
#   'not recall',
#   'neglect',
#   'overlook running'],
#  'forth': ['depart',
#   'forwards',
#   'show',
#   'phrase',
#   'extract',
#   'outward',
#   'out',
#   'put forward',
#   'to and fro',
#   'onward',
#   'onwards',
#   'forward',
#   'across',
#   'advance',
#   'express',
#   'make known',
#   'back and forth',
#   'on',
#   'about',
#   'into view',
#   'backwards and forwards',
#   'leave',
#   'bring out',
#   'and the like',
#   'go out',
#   'etcetera'],
#  'forward': ['over',
#   'expect',
#   'out',
#   'wait for',
#   'onward',
#   'move ahead',
#   'move on',
#   'forth',
#   'frontward',
#   'to the front',
#   'take ahead',
#   'advance',
#   'earlier',
#   'look ahead to',
#   'future focused',
#   'move earlier',
#   'front',
#   'along',
#   'on',
#   'look to the future',
#   'ahead',
#   'anticipate',
#   'excited about',
#   'anticipative'],
#  'fresh': ['relevant',
#   'modern',
#   'raw',
#   'bright',
#   'another',
#   'different',
#   'vivid',
#   'uncanned',
#   'unprocessed',
#   'pure',
#   'forward',
#   'airy',
#   'uncontaminated',
#   'new',
#   'nonfrozen',
#   'recent',
#   'novel',
#   'refreshing',
#   'clear',
#   'clean',
#   'impertinent',
#   'undimmed',
#   'original'],
#  'full': ['all out',
#   'loaded with',
#   'brimming with',
#   'total',
#   'generous',
#   'replete with',
#   'top',
#   'covered with',
#   'filled',
#   'complete',
#   'ample',
#   'big',
#   'gathered',
#   'packed with',
#   'highest',
#   'entire',
#   'crammed with',
#   'filled with',
#   'maximum',
#   'abundant',
#   'voluminous',
#   'overflowing',
#   'ruched',
#   'whole'],
#  'function': ['correspondence',
#   'related to',
#   'task',
#   'subroutine',
#   'phenomenon',
#   'working',
#   'sequence',
#   'calculation',
#   'equation',
#   'mapping',
#   'feature',
#   'job',
#   'role',
#   'purpose',
#   'activity',
#   'performance',
#   'operation',
#   'transformation',
#   'relation',
#   'result'],
#  'fundamental': ['foundational',
#   'major',
#   'central',
#   'radical',
#   'primary',
#   'elemental',
#   'underlying',
#   'necessary',
#   'important',
#   'significant',
#   'basic',
#   'elementary',
#   'vital',
#   'intrinsic',
#   'essential'],
#  'gall': ['blister',
#   'nerve',
#   'bile',
#   'poison',
#   'grub',
#   'temerity',
#   'cheek',
#   'bitter spirit',
#   'bile-producing',
#   'secretion  producing',
#   'audacity',
#   'rancor',
#   'abnormal growth',
#   'unknown person',
#   'pustule',
#   'pn',
#   'impudence',
#   'effrontery'],
#  'get': ['be',
#   'buy',
#   'bring',
#   'give',
#   'receive',
#   'procure',
#   'travel',
#   'acquire',
#   'reach',
#   'obtain',
#   'travel to',
#   'fetch',
#   'arrive at',
#   'persuade',
#   'gain',
#   'have',
#   'go',
#   'become',
#   'convince',
#   'wind up',
#   'achieve'],
#  'girl': ['woman',
#   'young female',
#   'lass',
#   'female children',
#   'female child',
#   'gal',
#   'young woman',
#   'female',
#   'child',
#   'miss',
#   'she'],
#  'go': ['set off',
#   'move',
#   'rest',
#   'walk',
#   'travel down',
#   'undertake',
#   'pass',
#   'leave',
#   'proceed',
#   'travel',
#   'engage in',
#   'start',
#   'attack',
#   'take',
#   'approach',
#   'be',
#   'run',
#   'relax',
#   'loose',
#   'reach',
#   'free',
#   'aim',
#   'running',
#   'journey',
#   'attempt',
#   'work',
#   'try',
#   'endure',
#   'release',
#   'operate'],
#  'good': ['satisfactory',
#   'beneficial',
#   'comfortable',
#   'enjoyable',
#   'respectable',
#   'minimum',
#   'esteem',
#   'happiness',
#   'standing',
#   'decent',
#   'character',
#   'thorough',
#   'reputation',
#   'easy',
#   'well regarded',
#   'nice',
#   'full',
#   'amiable',
#   'pleasant',
#   'favourable',
#   'commendable',
#   'significant',
#   'excellent',
#   'competent',
#   'considerable',
#   'effective',
#   'at least',
#   'friendliness',
#   'large',
#   'healthy',
#   'substantial',
#   'reasonable',
#   'fun',
#   'happy',
#   'cordiality',
#   'well behaved'],
#  'grim': ['unrelenting',
#   'horrific',
#   'doom laden',
#   'forbidding',
#   'ghastly',
#   'stern',
#   'doomy',
#   'harsh',
#   'horrid',
#   'negative',
#   'unpromising',
#   'unpleasant',
#   'morbid',
#   'horrible',
#   'harrowing',
#   'difficult',
#   'depressing',
#   'gloomy',
#   'dismal',
#   'dire',
#   'awful',
#   'gruesome',
#   'bleak',
#   'dark',
#   'sinister',
#   'terrible',
#   'appalling',
#   'severe',
#   'serious'],
#  'hard': ['strongly',
#   'diligently',
#   'closely',
#   'heavily',
#   'violently',
#   'fiercely',
#   'carefully',
#   'strenuously',
#   'aggressive',
#   'firmly',
#   'intensively',
#   'forcefully',
#   'tightly',
#   'seriously',
#   'earnestly',
#   'intently',
#   'badly',
#   'intensely',
#   'harshly',
#   'determinedly',
#   'severely',
#   'keenly',
#   'sufficiently',
#   'arduously',
#   'persistently'],
#  'heap': ['category',
#   'assortment',
#   'mess',
#   'lump',
#   'wreck',
#   'lots',
#   'state',
#   'collection',
#   'a lot',
#   'tons',
#   'pile',
#   'bundle',
#   'untidy pile',
#   'mound',
#   'loads',
#   'bin'],
#  'heavy': ['constant',
#   'weighty',
#   'hard',
#   'strongest',
#   'substantial',
#   'tough',
#   'abundant',
#   'tedious',
#   'onerous',
#   'harsh',
#   'costly',
#   'extensive',
#   'difficult',
#   'laboured',
#   'wieldy',
#   'ample',
#   'big',
#   'overweight',
#   'fat',
#   'dark',
#   'regular',
#   'worst',
#   'most abundant',
#   'stout',
#   'strong',
#   'considerable',
#   'wide ranging',
#   'excessive',
#   'severe',
#   'massive',
#   'wild',
#   'serious',
#   'most intense',
#   'profuse',
#   'frequent'],
#  'hold': ['own',
#   'stand up',
#   'have',
#   'carry',
#   'support',
#   'cache',
#   'adhere',
#   'occupy',
#   'call',
#   'take',
#   'convene',
#   'organise',
#   'store',
#   'grip',
#   'handle',
#   'conduct',
#   'host',
#   'lift',
#   'retain',
#   'put',
#   'believe',
#   'clasp',
#   'possess',
#   'clutch',
#   'keep',
#   'maintain',
#   'place',
#   'stand',
#   'contain',
#   'grasp',
#   'position'],
#  'informal': ['not rigorous',
#   'lacking rigour',
#   'commonly used',
#   'spontaneous',
#   'relaxed',
#   'approximate',
#   'everyday',
#   'unofficial',
#   'friendly',
#   'not prescribed',
#   'ordinary',
#   'untrained',
#   'imprecise',
#   'casual',
#   'easygoing'],
#  'inner': ['spiritual',
#   'central',
#   'mental',
#   'inward',
#   'inside',
#   'under',
#   'innermore',
#   'private',
#   'internal',
#   'enclosed',
#   'clique',
#   'interior',
#   'close',
#   'inmost',
#   'original',
#   'focal',
#   'trusted group'],
#  'instead': ['alternately',
#   'in its place',
#   'in place',
#   'in preference to',
#   'rather',
#   'alternatively',
#   'rather than',
#   'in place of this',
#   'but',
#   'in preference',
#   'in lieu',
#   'as an alternative'],
#  'investigator': ['detective',
#   'examiner',
#   'researcher',
#   'official',
#   'experimenter',
#   'officer',
#   'inquirer',
#   'inspector'],
#  'jam': ['malfunction',
#   'heavy traffic',
#   'impromptu music session',
#   'seizure',
#   'jelly',
#   'session',
#   'conserve',
#   'music session',
#   'gig',
#   'traffic block',
#   'preserve',
#   'music sessions',
#   'congestion',
#   'impromptu music',
#   'blockage',
#   'improvised music',
#   'queue',
#   'riff',
#   'traffic congestion',
#   'improv',
#   'informal music',
#   'informal music session'],
#  'job': ['duty',
#   'function',
#   'task',
#   'place',
#   'business',
#   'career',
#   'assignment',
#   'work',
#   'functional',
#   'contract',
#   'matter',
#   'role',
#   'piece of work',
#   'position',
#   'responsibility',
#   'post',
#   'employment',
#   'bit'],
#  'late': ['after the usual',
#   'behind time',
#   'not on time',
#   'older than the norm',
#   'after normal time',
#   'latter part of',
#   'after the usual time',
#   'lately',
#   'current',
#   'behind',
#   'recent',
#   'tardy',
#   'recently',
#   'latterly',
#   'delayed',
#   'end of',
#   'last minute',
#   'At the end of the',
#   'at a later hour',
#   'well into',
#   'near the end of',
#   'older',
#   'far on',
#   'after the normal time',
#   'at the end of the',
#   'end of the',
#   'near end',
#   'at a later stage',
#   'behind schedule',
#   'overdue'],
#  'lead': ['prospect',
#   'precedence',
#   'direction',
#   'number one',
#   'initiative',
#   'foray',
#   'to the fore',
#   'forefront',
#   'story',
#   'wire',
#   'guide rope',
#   'hint',
#   'in front',
#   'guidance',
#   'tip',
#   'leash',
#   'conduct',
#   'prominent position',
#   'leader',
#   'flex',
#   'head',
#   'star',
#   'halter',
#   'clue',
#   'opportunity',
#   'command of',
#   'ahead',
#   'cable',
#   'front rank',
#   'influential',
#   'main role',
#   'most prominent',
#   'enticement',
#   'example'],
#  'let': ['inform people',
#   'give',
#   'give ',
#   'reduce',
#   'rent',
#   'have',
#   'authorise',
#   'advise',
#   'expel',
#   'tell',
#   'lease',
#   'forgive',
#   'free',
#   'diminish',
#   'hire',
#   'agree to',
#   'slacken',
#   'lessen',
#   'inform',
#   'tell people',
#   'allow',
#   'permit',
#   'release'],
#  'letter': ['correspondence',
#   'alphabet',
#   'alphabetic character',
#   'correspondence ',
#   'communication',
#   'memo',
#   'character',
#   'dispatch',
#   'note',
#   'epistle',
#   'mail',
#   'message',
#   'document',
#   'missive',
#   'glyph'],
#  'liberal': ['open minded',
#   'plentiful',
#   'generous',
#   'free thinking',
#   'ample',
#   'progressive',
#   'openhanded',
#   'humanitarian',
#   'left wing',
#   'free',
#   'tolerant',
#   'noninterventionist',
#   'liberated',
#   'broad minded',
#   'social',
#   'lenient',
#   'abundant',
#   'open',
#   'free market'],
#  'lie': ['can be found',
#   'untruths',
#   'reclined horizontally',
#   'rest',
#   'stretch out',
#   'fibbing',
#   'falsehoods',
#   'hide',
#   'be bury',
#   'sit',
#   'say untruthfully',
#   'had direction',
#   'fib',
#   'telling untruths',
#   'that was',
#   'arrange',
#   'situate',
#   'falsify',
#   'be',
#   'say falsely',
#   'recline horizontally',
#   'extend',
#   'get',
#   'recline',
#   'resting',
#   'stay',
#   'lay',
#   'put',
#   'be located',
#   'wait',
#   'leave',
#   'remain',
#   'place',
#   'deceive',
#   'position',
#   'telling falsehoods'],
#  'light': ['bright',
#   'portable',
#   'fair',
#   'simple',
#   'unsubstantial',
#   'easy',
#   'cheerful',
#   'gentle',
#   'mild',
#   'not heavy',
#   'ethereal',
#   'lightweight',
#   'less serious',
#   'luminous',
#   'pale',
#   'casual',
#   'restricted',
#   'faint',
#   'trivial',
#   'unheavy',
#   'frothy',
#   'upbeat',
#   'minor',
#   'easily digested',
#   'slight',
#   'inconsiderable',
#   'of little weight',
#   'undemanding',
#   'facile',
#   'pale ',
#   'small',
#   'small amounts of',
#   'entertaining',
#   'soft'],
#  'likewise': ['equally',
#   'equally ',
#   'similarly',
#   'also',
#   'correspondingly',
#   'the same',
#   'additionally'],
#  'live': ['powered',
#   'as it happens',
#   'direct',
#   'performed',
#   'animate',
#   'functioning',
#   'operative',
#   'living',
#   'working',
#   'realtime',
#   'on the spot',
#   'in real time',
#   'online',
#   'real',
#   'breathing',
#   'showing',
#   'circulated',
#   'sustainable',
#   'running',
#   'connected',
#   'active',
#   'as it happened',
#   'viewable',
#   'performing',
#   'existent',
#   'charged'],
#  'loud': ['heavy',
#   'imposing',
#   'obtrusive',
#   'disturbing',
#   'amplified',
#   'booming',
#   'vociferous',
#   'thundering',
#   'shrill',
#   'blaring',
#   'big',
#   'raucous',
#   'resonant',
#   'strong',
#   'strident',
#   'conspicuous',
#   'noisy',
#   'forceful',
#   'rowdy',
#   'powerful',
#   'deafening',
#   'clear'],
#  'mad': ['insane',
#   'crazy',
#   'rapid',
#   'wildly excited',
#   'very quickly',
#   'angry',
#   'hurried',
#   'uncontrolled',
#   'furious',
#   'very rapidly',
#   'frantic',
#   'fast',
#   'frenzied',
#   'very fast',
#   'wild',
#   'BSE',
#   'frenetic',
#   'pn',
#   'annoyed',
#   'rabid'],
#  'make': ['help',
#   'give rise to',
#   'enable to',
#   'cause to be',
#   'have',
#   'cause a great burden to be',
#   'compel me to',
#   'turn',
#   'perform',
#   'create',
#   'compel',
#   'construct',
#   'write',
#   'induce to',
#   'take',
#   'cause',
#   'cause to become',
#   'do',
#   'cause your outer work to be more',
#   'complete',
#   'form',
#   'reach',
#   'cause ',
#   'arrive at',
#   'produce',
#   'commit',
#   'cause to',
#   'affect',
#   'induce to be',
#   'generate',
#   'change',
#   'initiate',
#   'succeed',
#   'get to'],
#  'manage': ['control',
#   'administer',
#   'handle',
#   'success',
#   'oversee',
#   'conduct',
#   'contrive',
#   'direct',
#   'succeed in',
#   'take care of',
#   'deal with',
#   'run',
#   'succeed',
#   'organise',
#   'look after',
#   'undertake',
#   'govern',
#   'coordinate',
#   'endeavour',
#   'be able'],
#  'mass': ['ordinary people',
#   'weight',
#   'people',
#   'density',
#   'climax',
#   'the service',
#   'the Eucharist',
#   'crowd',
#   'populace',
#   'critical point',
#   'crucial level',
#   'common people',
#   'majority',
#   'splash',
#   'public',
#   'multitude',
#   'body',
#   'means',
#   'expanse',
#   'bulk',
#   'host',
#   'extent',
#   'aggregate',
#   'critical level',
#   'volume',
#   'throng',
#   'shock',
#   'conglomeration',
#   'magnitude',
#   'main population',
#   'proletariat',
#   'the celebration of the Eucharist',
#   'accumulation',
#   'quantity'],
#  'match': ['partnership',
#   'competition',
#   'event',
#   'competitor',
#   'fit',
#   'contest',
#   'pairing',
#   'bout',
#   'matchstick',
#   'couple',
#   'correspondence',
#   'hit',
#   'equivalent',
#   'choice',
#   'game',
#   'link',
#   'association',
#   'rival',
#   'equal',
#   'counterpart',
#   'marriage',
#   'correlation'],
#  'mission': ['negotiation',
#   'duty',
#   'office',
#   'delegation',
#   'preaching',
#   'church',
#   'operation',
#   'vocation',
#   'religious preaching',
#   'project',
#   'oratory',
#   'objective',
#   'arrival',
#   'assignment',
#   'outreach',
#   'quest',
#   'purpose',
#   'legation',
#   'charity',
#   'evangelical',
#   'ministering',
#   'task',
#   'work',
#   'calling',
#   'aim'],
#  'mood': ['demeanour',
#   'atmosphere',
#   'feeling',
#   'tone',
#   'form',
#   'humour',
#   'vibe',
#   'timbre',
#   'feel like writing',
#   'outlook',
#   'modality',
#   'ambience',
#   'attitude',
#   'frame of mind',
#   'mode',
#   'disposition',
#   'temperament',
#   'manner',
#   'state of mind',
#   'temper',
#   'mindset'],
#  'nasty': ['disagreeable',
#   'objectionable',
#   'vindictive',
#   'offensive',
#   'unpalatable',
#   'dangerous',
#   'malicious',
#   'spiteful',
#   'vicious',
#   'foul',
#   'formidable',
#   'vicioous',
#   'bad',
#   'unpleasant',
#   'inhospitable',
#   'dirty',
#   'horrible',
#   'annoying',
#   'bitter',
#   'painful',
#   'mean'],
#  'near': ['about',
#   'close at hand',
#   'practically',
#   'almost',
#   'neighbouring',
#   'close by',
#   'alongside',
#   'approximately',
#   'all but',
#   'just about',
#   'adjoining',
#   'virtually',
#   'closely',
#   'close',
#   'not remotely',
#   'approaching',
#   'not closely',
#   'nearly',
#   'close to'],
#  'nearly': ['practically',
#   'almost',
#   'anything like',
#   'anyway',
#   'approximately',
#   'remotely',
#   'half',
#   'anywhere near',
#   'quite',
#   'even approximately'],
#  'neat': ['compact',
#   'trim',
#   'great',
#   'good',
#   'ordered',
#   'nice',
#   'well-formulated',
#   'simple',
#   'tidy',
#   'uniform',
#   'terrific',
#   'orderly',
#   'clever',
#   'pleasing',
#   'order',
#   'smart',
#   'cool'],
#  'new': ['different',
#   'novel',
#   'additional',
#   'extra',
#   'distinct',
#   'modern',
#   'younger',
#   'recently started',
#   'recently acquired',
#   'current',
#   'other',
#   'another',
#   'fresh',
#   'further',
#   'latest',
#   'original',
#   'succeeding',
#   'recent'],
#  'now': ['the present',
#   'just',
#   'at present',
#   'these days',
#   'next',
#   'nowadays',
#   'this moment',
#   'since',
#   'perhaps',
#   'currently',
#   'lately',
#   'today',
#   'instantly',
#   'recently',
#   'presently',
#   'this time',
#   'this point',
#   'at this point',
#   'of late',
#   'at this time',
#   'immediately',
#   'as a result',
#   'at this stage',
#   'well',
#   'so',
#   'consequently'],
#  'often': ['regularly',
#   'at times',
#   'recurrently',
#   'habitually',
#   'sometimes',
#   'generally',
#   'commonly',
#   'much',
#   'occasionally',
#   'usually',
#   'frequently'],
#  'only': ['uniquely',
#   'nothing but',
#   'simply to',
#   'just',
#   'hardly',
#   'merely',
#   'barely',
#   'no more than',
#   'exclusively',
#   'singularly',
#   'purely',
#   'just now',
#   'recently',
#   'solely'],
#  'open': ['accessible',
#   'exposed',
#   'unlidded',
#   'unfastened',
#   'unobstructed',
#   'sandal',
#   'unclosed',
#   'working',
#   'unlocked',
#   'susceptible',
#   'unpoliced',
#   'unshut',
#   'gaping',
#   'switched on',
#   'empty',
#   'available',
#   'peeled',
#   'accepting business',
#   'free',
#   'aware',
#   'approachable',
#   'ajar',
#   'peep',
#   'alert',
#   'unrestricted',
#   'wide',
#   'receptive',
#   'green',
#   'ready for business',
#   'clear'],
#  'order': ['sort',
#   'purchase',
#   'buy',
#   'organise',
#   'grade',
#   'manage',
#   'request',
#   'direct',
#   'rank',
#   'instruct',
#   'put in order',
#   'send',
#   'mandate',
#   'apply for',
#   'command',
#   'plan',
#   'reserve',
#   'tell',
#   'arrange'],
#  'outdoor': ['uncovered',
#   'all-weather',
#   'outward-bound',
#   'outside',
#   'open-air',
#   'external',
#   'roadside',
#   'alfresco'],
#  'paper': ['essay',
#   'toilet tissue',
#   'publication',
#   'manuscript',
#   'journal',
#   'study',
#   'bathroom tissue',
#   'papyrus',
#   'newspaper',
#   'thesis',
#   'stationery',
#   'report',
#   'article',
#   'document',
#   'presentation',
#   'roll',
#   'treatise'],
#  'pass': ['transpire',
#   'authorise',
#   'go by',
#   'give',
#   'navigate',
#   'get through',
#   'traverse',
#   'see',
#   'go',
#   'skirt',
#   'occur',
#   'disappear',
#   'hand over',
#   'proceed',
#   'transfer',
#   'ratify',
#   'send',
#   'meet approval',
#   'measure up to a certain standard',
#   'expire',
#   'approach',
#   'satisfy',
#   'successfully complete',
#   'finish',
#   'go away',
#   'deliver',
#   'get approval from',
#   'hand',
#   'succeed',
#   'ebb away',
#   'succeed at',
#   'elapse',
#   'go past',
#   'adopt',
#   'flow',
#   'go ',
#   'experience',
#   'succeed in',
#   'leak',
#   'move through',
#   'approve',
#   'be accepted by'],
#  'phone': ['phoneme',
#   'sound',
#   'mobile phone',
#   'telecom',
#   'phonetic unit',
#   'mobile',
#   'allophone',
#   'handset',
#   'telephone',
#   'sound unit',
#   'sonant',
#   'mobile telephone',
#   'speech',
#   'cellular',
#   'telecommunication'],
#  'poor': ['unsatisfactory',
#   'inadequate',
#   'wretched',
#   'pitiable',
#   'low income',
#   'less well off',
#   'miserable',
#   'mediocre',
#   'destitute',
#   'indigent',
#   'needy',
#   'unhappy',
#   'unlucky',
#   'low',
#   'unfortunate',
#   'sorry',
#   'impoverished',
#   'infertile',
#   'inferior',
#   'underprivileged',
#   'poverty stricken',
#   'weak',
#   'hapless',
#   'developing',
#   'deficient',
#   'deprived',
#   'incompetent',
#   'bad',
#   'substandard'],
#  'possibly': ['necessarily',
#   'believably',
#   'conceivably',
#   'perhaps',
#   'maybe',
#   'reasonably',
#   'plausibly',
#   'feasibly',
#   'potentially',
#   'at all',
#   'ever'],
#  'post': ['fence',
#   'upright',
#   'pole',
#   'marker',
#   'message',
#   'employment',
#   'announcement',
#   'date',
#   'support',
#   'stake',
#   'station',
#   'role',
#   'mail',
#   'boundary',
#   'lookout',
#   'mail carrier',
#   'postal service',
#   'appointment',
#   'the job',
#   'job',
#   'situation',
#   'electronic mail',
#   'electronic bulletin',
#   'target',
#   'post office',
#   'crossing',
#   'position'],
#  'pot': ['stake',
#   'container',
#   'pourer',
#   'dope',
#   'ceramic',
#   'bowl',
#   'marijuana',
#   'weed',
#   'cannabis',
#   'canister',
#   'casserole',
#   'saucepan',
#   'vessel',
#   'tub',
#   'winning',
#   'tray',
#   'teapot',
#   'pan',
#   'prize'],
#  'pound': ['twelve shillings',
#   'weight',
#   'dollar',
#   'kilo',
#   'hammer',
#   'enclosure',
#   'lb',
#   'sixteen ounces',
#   'quid',
#   'lot',
#   'prison',
#   'pn',
#   'store',
#   'sterling',
#   'beat',
#   'thump',
#   '11.27 kilograms',
#   'cage',
#   '16 ounces',
#   'per ounces',
#   'throb',
#   'kilogram',
#   'kennel'],
#  'profound': ['penetrating',
#   'sagacious',
#   'deep',
#   'thoughtful',
#   'huge',
#   'keen',
#   'thorough',
#   'complex',
#   'extensive',
#   'thought provoking',
#   'insightful',
#   'pronounced',
#   'in depth',
#   'important',
#   'intellectual',
#   'significant',
#   'intense',
#   'acute',
#   'great',
#   'wise',
#   'far reaching',
#   'discerning ',
#   'deep seated',
#   'serious'],
#  'prominent': ['widely known',
#   'renowned',
#   'salient',
#   'prevalent',
#   'noticeable',
#   'visible',
#   'leading',
#   'notable',
#   'eminent',
#   'well known',
#   'famous',
#   'important',
#   'obvious',
#   'significant',
#   'high profile',
#   'pronounced',
#   'major',
#   'foremost',
#   'conspicuous'],
#  'pull': ['move',
#   'lure',
#   'rip',
#   'heave',
#   'manipulate',
#   'do everything it takes',
#   'stretch',
#   'attract',
#   'tow',
#   'get hold of',
#   'stop the car',
#   'draw',
#   'look at',
#   'read',
#   'stop',
#   'stop at the side of the road',
#   'park',
#   'pluck',
#   'drag',
#   'squeeze',
#   'tug',
#   'extract',
#   'go to any length',
#   'stop at nothing',
#   'shift',
#   'request',
#   'haul',
#   'remove',
#   'try everything',
#   'wrench',
#   'withdraw',
#   'draw ',
#   'push',
#   'yank'],
#  'pulse': ['heart',
#   'heartrate',
#   'force',
#   'emanation',
#   'energy',
#   'lifeblood',
#   'heartbeat rate',
#   'vibration',
#   'beep',
#   'throb',
#   'rhythm',
#   'reflex',
#   'centre',
#   'beat',
#   'wave',
#   'heartbeat',
#   'sound',
#   'stimulus',
#   'legume',
#   'hearbeat',
#   'edible seed',
#   'throbbing'],
#  'put': ['set',
#   'give to',
#   'give',
#   'lay',
#   'phrase',
#   'allay',
#   'provide',
#   'make',
#   'send',
#   'state',
#   'collate',
#   'lay down',
#   'dismiss',
#   'get',
#   'propose',
#   'express',
#   'nullify',
#   'propound',
#   'fasten',
#   'assemble',
#   'present',
#   'advance',
#   'join',
#   'gather',
#   'remove',
#   'leave',
#   'collect',
#   'settle',
#   'place',
#   'allow',
#   'position',
#   'put an end to',
#   'fix',
#   'stick'],
#  'quick': ['rapid',
#   'prompt',
#   'concise',
#   'hasty',
#   'cursory',
#   'express',
#   'brief',
#   'fast',
#   'keen',
#   'short',
#   'speedy',
#   'immediate',
#   'expeditious',
#   'swift',
#   'hurried',
#   'waste no time in'],
#  'range': ['breadth',
#   'selection',
#   'extent',
#   'series',
#   'area',
#   'array',
#   'assortment',
#   'practice area',
#   'span',
#   'variety',
#   'access',
#   'spread',
#   'total freedom',
#   'scope',
#   'complete gamut',
#   'run',
#   'free run',
#   'collection',
#   'choice',
#   'coverage',
#   'roaming',
#   'gallery',
#   'distance',
#   'shooting centre',
#   'shooting area',
#   'limit'],
#  'rather': ['preferably',
#   'fairly',
#   'significantly',
#   'in preference to',
#   'very',
#   'moderately',
#   'sooner',
#   'instead of',
#   'somewhat',
#   'instead',
#   'more accurately',
#   'quite',
#   'slightly',
#   'more'],
#  'raw': ['poor treatment',
#   'exposed',
#   'excoriated',
#   'unfair',
#   'bloody',
#   'rough',
#   'open',
#   'genuine',
#   'harsh',
#   'unspun',
#   'unprocessed',
#   'uncompressed',
#   'basic',
#   'crude',
#   'immature',
#   'harsh deal',
#   'rudimentary',
#   'unrefined',
#   'unfair deal',
#   'austere',
#   'undressed',
#   'untreated',
#   'natural',
#   'refreshing',
#   'unspoilt',
#   'naked',
#   'untaught',
#   'bad',
#   'unsophisticated',
#   'uncooked',
#   'inexperienced'],
#  'really': ['totally',
#   'unreservedly',
#   'effectively',
#   'very',
#   'indeed',
#   'in fact',
#   'exceptionally',
#   'unquestionably',
#   'truly',
#   'absolutely',
#   'completely',
#   'definitely',
#   'honestly',
#   'properly',
#   'actually',
#   'extremely',
#   'genuinely'],
#  'reasonable': ['credible',
#   'just',
#   'appropriate',
#   'sensible',
#   'fair',
#   'justifiable',
#   'enough',
#   'rational',
#   'adequate',
#   'moderate',
#   'tolerable',
#   'affordable',
#   'good',
#   'sufficient',
#   'high enough',
#   'well-judged',
#   'good value',
#   'equitable',
#   'manageable',
#   'measured',
#   'reliable',
#   'inexpensive',
#   'likely',
#   'acceptable'],
#  'remainder': ['residue',
#   'surplus',
#   'cut price',
#   'residual',
#   'rest',
#   'leftover part',
#   'leftover',
#   'balance',
#   'second hand'],
#  'render': ['portray',
#   'represent',
#   'convert',
#   'give',
#   'provide',
#   'give ',
#   'make',
#   'show',
#   'deliver',
#   'use',
#   'submit',
#   'display',
#   'leave',
#   'encode',
#   'bestow',
#   'cause to be',
#   'lay out',
#   'create'],
#  'rest': ['inactivity',
#   'service',
#   'stick',
#   'remains',
#   'layby',
#   'support',
#   'comfort',
#   'leisure',
#   'quiet',
#   'repose',
#   'prop',
#   'break',
#   'convenience',
#   'base',
#   'sleep',
#   'respite',
#   'break area',
#   'service station',
#   'balance',
#   'remainder',
#   'stand'],
#  'return': ['retrieve',
#   'go',
#   'take back',
#   'retrace',
#   'make',
#   'resume',
#   'get back',
#   'revisit',
#   'give back',
#   'reply to',
#   'repeat',
#   'get',
#   'send back',
#   'produce',
#   'go back',
#   'go back to',
#   'realize',
#   'bring back',
#   'earn',
#   'respond to',
#   'come back',
#   'revert',
#   'yield',
#   'regress'],
#  'rhythm': ['regular beat',
#   'form',
#   'clock',
#   'beat',
#   'pattern',
#   'tempo',
#   'pulse',
#   'harmony',
#   'time signature',
#   'regular pattern',
#   'cadence',
#   'cycle'],
#  'rich': ['detailed',
#   'full',
#   'well-off',
#   'ample',
#   'lavish',
#   'vibrant',
#   'elaborate',
#   'packed with',
#   'lush',
#   'detail',
#   'valuable',
#   'high',
#   'full of',
#   'rewarding',
#   'abounding',
#   'significant',
#   'wealthy',
#   'abundant'],
#  'right': ['straightaway',
#   'all the way',
#   'just',
#   'directly',
#   'straight',
#   'exactly',
#   'well',
#   'accurately',
#   'appropriate',
#   'properly',
#   'correctly',
#   'immediately',
#   'totally',
#   'correct'],
#  'ring': ['connotation',
#   'tone',
#   'chain',
#   'bell',
#   'feel',
#   'hoop',
#   'telephone call',
#   'rim',
#   'chime',
#   'group',
#   'network',
#   'call',
#   'fob',
#   'circle',
#   'circlet',
#   'band',
#   'syndicate',
#   'coil',
#   'shadow',
#   'holder',
#   'association',
#   'sound',
#   'level',
#   'orbit',
#   'loop'],
#  'rough': ['tough',
#   'simple',
#   'hard',
#   'general',
#   'not smooth',
#   'violent',
#   'jagged',
#   'uneven',
#   'unfinished',
#   'broad',
#   'approximate',
#   'unpleasant',
#   'coarse',
#   'basic',
#   'crude',
#   'difficult',
#   'poor',
#   'imperfect',
#   'rudimentary',
#   'inexact',
#   'demanding',
#   'unrefined',
#   'raucous',
#   'preliminary',
#   'vague',
#   'uncut',
#   'harsh',
#   'disorderly',
#   'irregular',
#   'uncivil',
#   'dangerous',
#   'wild',
#   'hard time'],
#  'rude': ['primitive',
#   'naughty',
#   'abusive',
#   'raw',
#   'sudden',
#   'rough',
#   'lewd',
#   'savage',
#   'unkind',
#   'insulting',
#   'vulgar',
#   'offensive',
#   'approximate',
#   'unpleasant',
#   'coarse',
#   'basic',
#   'crude',
#   'surprise',
#   'disrespectful',
#   'rudimentary',
#   'inexact',
#   'unrefined',
#   'unfinished',
#   'awkward',
#   'impolite',
#   'ill mannered',
#   'abrupt',
#   'wild'],
#  'run': ['control',
#   'go against',
#   'flow',
#   'manage',
#   'be published',
#   'go',
#   'sprint',
#   'functioning',
#   'chair',
#   'fill',
#   'use',
#   'total',
#   'appear',
#   'working',
#   'stretch',
#   'avoid',
#   'appear in sequence',
#   'try to escape',
#   'include',
#   'function',
#   'handle',
#   'complete',
#   'extend',
#   'be serialised',
#   'execute',
#   'continue for',
#   'govern',
#   'flee',
#   'proceed',
#   'training',
#   'last',
#   'contradict',
#   'work',
#   'cover',
#   'scurry',
#   'organise',
#   'operate',
#   'rush'],
#  'saint': ['paladin',
#   'good',
#   'figure',
#   'angel',
#   'prophet',
#   'blessed',
#   'canonised person',
#   'holy man',
#   'canonised',
#   'holy woman',
#   'martyr',
#   'pn',
#   'disciple',
#   'holy person',
#   'goodman'],
#  'scene': ['sequence',
#   'image',
#   'site',
#   'community',
#   'sphere',
#   'sight',
#   'event',
#   'landscape',
#   'scale',
#   'area',
#   'environment',
#   'field',
#   'setting',
#   'location',
#   'picture',
#   'business',
#   'incident',
#   'part',
#   'backstage',
#   'segment',
#   'stage',
#   'arena',
#   'level',
#   'place',
#   'act',
#   'programme'],
#  'scrap': ['discarded item',
#   'album',
#   'clipping',
#   'piece',
#   'crumb',
#   'fragment',
#   'recycling',
#   'morsel',
#   'collage',
#   'shred',
#   'odds and ends',
#   'rubbish',
#   'waste metal',
#   'leftover',
#   'bit',
#   'waste',
#   'remainder',
#   'trade in'],
#  'secret': ['innermost',
#   'unseen',
#   'confidential',
#   'unrevealed',
#   'spying',
#   'clandestine',
#   'unpublished',
#   'classified',
#   'undisclosed',
#   'private',
#   'intelligence agency',
#   'unspoken',
#   'coded',
#   'concealed',
#   'closed',
#   'unknown',
#   'intelligence',
#   'hidden',
#   'undercover',
#   'inner'],
#  'see': ['consider',
#   'discover',
#   'establish',
#   'find',
#   'witness',
#   'detect',
#   'visit',
#   'note',
#   'behold',
#   'find out',
#   'notice',
#   'look at',
#   'watch',
#   'perceive',
#   'observe',
#   'understand',
#   'distinguish',
#   'ascertain',
#   'experience',
#   'learn',
#   'undergo',
#   'view'],
#  'serious': ['real',
#   'heavy',
#   'take action',
#   'impressive',
#   'businesslike',
#   'grave',
#   'resolute',
#   'concerned',
#   'major',
#   'urgent',
#   'severe',
#   'substantial',
#   'critical',
#   'significant',
#   'acute',
#   'proper',
#   'important',
#   'considerable',
#   'sincere'],
#  'severely': ['badly',
#   'critically',
#   'heavily',
#   'gravely',
#   'highly',
#   'sternly',
#   'seriously',
#   'devastatingly',
#   'harshly',
#   'extremely',
#   'dramatically'],
#  'shade': ['tone',
#   'echo',
#   'based on',
#   'nuance',
#   'tint',
#   'degree',
#   'hint',
#   'gradation',
#   'shadow ',
#   'hue',
#   'sunglasses',
#   'trace',
#   'shelter',
#   'screen',
#   'shadow',
#   'colour',
#   'cover',
#   'under the cover',
#   'depth',
#   'suggestion',
#   'canopy',
#   'tinge'],
#  'shed': ['relinquish',
#   'reveal',
#   'give',
#   'discarding',
#   'get rid of',
#   'drop',
#   'radiate',
#   'emit',
#   'give off',
#   'scatter',
#   'moult',
#   'spill',
#   'spread',
#   'disperse',
#   'lose',
#   'transmit',
#   'discard',
#   'pass',
#   'throw',
#   'cast off',
#   'shine'],
#  'shortly': ['curtly',
#   'briefly',
#   'presently',
#   'just',
#   'not long',
#   'almost immediately',
#   'soon',
#   'before long',
#   'quickly',
#   'brusquely',
#   'sharply',
#   'a little',
#   'immediately',
#   'little',
#   'abruptly'],
#  'shot': ['photo',
#   'move',
#   'stroke',
#   'portrait',
#   'vaccination',
#   'manoeuvre',
#   'strike',
#   'ammunition',
#   'jab',
#   'picture',
#   'play',
#   'noise',
#   'hit',
#   'discharge',
#   'injection',
#   'blast',
#   'pellet',
#   'photograph',
#   'attempt',
#   'bullet',
#   'firing',
#   'drive',
#   'aim',
#   'projectile',
#   'inoculation',
#   'round'],
#  'show': ['exhibit',
#   'give',
#   'instruct',
#   'present with',
#   'put on',
#   'be revealed',
#   'illustrate',
#   'demonstrate to',
#   'appear',
#   'indicate',
#   'be displayed',
#   'picture',
#   'play',
#   'display ',
#   'offer',
#   'depict',
#   'guide',
#   'indicate to',
#   'come',
#   'present',
#   'be seen',
#   'reveal',
#   'do not appear',
#   'air',
#   'display'],
#  'side': ['divide',
#   'surface',
#   'perspective',
#   'aspect',
#   'conversely',
#   'other hand',
#   'area',
#   'dividing line',
#   'flank',
#   'instead',
#   'you',
#   'for us',
#   'ally',
#   'contingent',
#   'faction',
#   'hand',
#   'part',
#   'standpoint',
#   'boundary',
#   'bank',
#   'fringe',
#   'against',
#   'facet',
#   'from you',
#   'shore',
#   'edge',
#   'responsibility',
#   'team',
#   'position',
#   'view'],
#  'skip': ['omit',
#   'bump',
#   'spring',
#   'bound',
#   'bounce',
#   'jump',
#   'skim',
#   'pass',
#   'miss',
#   'leave',
#   'avoid',
#   'hop',
#   'reject',
#   'pass over',
#   'dodge',
#   'skitter',
#   'prance',
#   'shift',
#   'jump over',
#   'miss out',
#   'ignore',
#   'eschew',
#   'disregard',
#   'neglect',
#   'fail once'],
#  'so': ['or more',
#   'in a way',
#   'very',
#   'likewise',
#   'that',
#   'thus',
#   'hence',
#   'approximately',
#   'this',
#   'as',
#   'about ',
#   'as we',
#   'as it were',
#   'thereabouts',
#   'consequently',
#   'one might say',
#   'therefore'],
#  'soft': ['spongy',
#   'comfortable',
#   'nonalcoholic',
#   'tender',
#   'yielding',
#   'not rough',
#   'nonalcoholic drinks',
#   'faint',
#   'comfy',
#   'malleable',
#   'easy',
#   'flexible',
#   'lenient',
#   'weak',
#   'feeble',
#   'squashy',
#   'undemanding',
#   'gentle',
#   'imprecise',
#   'compassionate',
#   'smooth',
#   'quiet',
#   'cushioned',
#   'restful'],
#  'softly': ['indifferently',
#   'quietly',
#   'lightly',
#   'delicately',
#   'slightly',
#   'tenderly',
#   'faintly',
#   'gently',
#   'finely',
#   'carefully',
#   'daintily',
#   'subtly'],
#  'soil': ['the ground',
#   'layer',
#   'land',
#   'dirt',
#   'tarnish',
#   'pn',
#   'terrain',
#   'geological',
#   'compost',
#   'layer of earth',
#   'earth',
#   'stain',
#   'pedological',
#   'ground'],
#  'solid': ['set',
#   'secure',
#   'accurate',
#   'hard',
#   'respectable',
#   'substantial',
#   'cemented',
#   'genuine',
#   'valid',
#   'dependable',
#   'stable',
#   'firm',
#   'sound',
#   'good',
#   'convincing',
#   'rigid',
#   'strong',
#   'dry',
#   'sturdy',
#   'solid',
#   'reliable',
#   'substantive',
#   'concrete',
#   'fixed'],
#  'special': ['exclusive',
#   'remarkable',
#   'extra',
#   'abnormal',
#   'treasured',
#   'quality',
#   'additional',
#   'selected',
#   'eminent',
#   'specifically designed',
#   'wonderful',
#   'lovely',
#   'premium',
#   'exceptional',
#   'kind',
#   'extraordinary',
#   'important',
#   'particular',
#   'memorable',
#   'unique',
#   'peculiar',
#   'tailored',
#   'valued',
#   'atypical',
#   'anomalous',
#   'magical',
#   'outstanding',
#   'distinguished'],
#  'stand': ['represent',
#   'abbreviate',
#   'frame',
#   'attitude',
#   'table',
#   'prevail',
#   'rely',
#   'sit',
#   'remain inactive',
#   'support',
#   'remain aloof',
#   'platform',
#   'location',
#   'do-nothing',
#   'remain immobile',
#   'be resolute',
#   'stance',
#   'watch',
#   'stay',
#   'base',
#   'upright',
#   'look on',
#   'structure',
#   'wait',
#   'placement',
#   'remain upright',
#   'remain',
#   'continue',
#   'place',
#   'endure',
#   'position',
#   'symbolize'],
#  'steady': ['firm',
#   'unwavering',
#   'sure',
#   'constant',
#   'solid',
#   'gradual',
#   'unchanging',
#   'continuous',
#   'constant ',
#   'unvarying',
#   'persistent',
#   'unshaking',
#   'regular',
#   'unremitting',
#   'unfluctuating',
#   'stable',
#   'uninterrupted',
#   'fixed',
#   'unbroken'],
#  'stiff': ['heavy',
#   'rheumatic',
#   'tough',
#   'hard',
#   'powerful',
#   'inflexible',
#   'stern',
#   'constrained',
#   'inelastic',
#   'harsh',
#   'unnatural',
#   'aching',
#   'unrelaxed',
#   'painful',
#   'firm',
#   'good',
#   'sore',
#   'unyielding',
#   'rigid',
#   'strong',
#   'intense',
#   'formal',
#   'unbending',
#   'solid',
#   'cricked',
#   'frozen',
#   'severe'],
#  'still': ['serene',
#   'motionless',
#   'arranged',
#   'not windy',
#   'unmoving',
#   'hushed',
#   'smooth',
#   'quiet',
#   'static',
#   'windless',
#   'nonmoving',
#   'peaceful',
#   'unruffled',
#   'tranquil',
#   'fixed',
#   'stationary',
#   'calm'],
#  'straight': ['right',
#   'accurate',
#   'direct',
#   'uninterrupted',
#   'undiluted',
#   'genuine',
#   'unadulterated',
#   'in order',
#   'undistorted',
#   'uncrooked',
#   'heterosexual',
#   'in a row',
#   'pure',
#   'consecutive',
#   'truthful',
#   'correct',
#   'uncurved',
#   'linear',
#   'vertical',
#   'continuous',
#   'standard',
#   'unbending',
#   'unswerving',
#   'candid',
#   'unbent',
#   'successive',
#   'sorted',
#   'true',
#   'level',
#   'nondeviating',
#   'plain',
#   'clear',
#   'smooth',
#   'honest',
#   'orderly',
#   'forthright',
#   'uncurving',
#   'undeviating'],
#  'strain': ['load',
#   'exertion',
#   'melody',
#   'worry',
#   'group',
#   'trace',
#   'variety',
#   'breed',
#   'extraction',
#   'music',
#   'type',
#   'stock',
#   'sort',
#   'tension',
#   'form',
#   'kind',
#   'pressure',
#   'burden',
#   'line',
#   'effort',
#   'tune',
#   'stress',
#   'anxiety'],
#  'strange': ['unusual',
#   'unexpected',
#   'surprising',
#   'peculiar',
#   'unknown',
#   'abnormal',
#   'different',
#   'unfamiliar',
#   'foreign',
#   'alien',
#   'unlikely',
#   'weird',
#   'odd',
#   'bizarre'],
#  'strike': ['occur to',
#   'bump',
#   'move',
#   'fail',
#   'hammer',
#   'find',
#   'seem to',
#   'make',
#   'appear to',
#   'occur',
#   'hitting',
#   'start',
#   'take',
#   'carve',
#   'surprise',
#   'pn',
#   'achieve',
#   'begin',
#   'hit',
#   'get',
#   'impress',
#   'arrive at',
#   'bang',
#   'thrust',
#   'affect',
#   'bash',
#   'knock',
#   'cast',
#   'collide with'],
#  'strong': ['heavy',
#   'capable',
#   'tough',
#   'secure',
#   'resolute',
#   'powerful',
#   'potent',
#   'high',
#   'hardy',
#   'well stocked',
#   'keen',
#   'distinct',
#   'durable',
#   'compelling',
#   'resilient',
#   'dependable',
#   'bitter',
#   'firm',
#   'concentrated',
#   'good',
#   'vigorous',
#   'pronounced',
#   'full bodied',
#   'masterful',
#   'convincing',
#   'highly flavoured',
#   'dark',
#   'robust',
#   'intense',
#   'sound',
#   'effective',
#   'sturdy',
#   'solid',
#   'clear',
#   'persuasive',
#   'healthy',
#   'forceful'],
#  'suffer': ['bear',
#   'feel',
#   'acquire',
#   'tolerate',
#   'experience',
#   'put up with',
#   'accept',
#   'sustain',
#   'endure',
#   'have',
#   'undergo',
#   'be subjected to',
#   'encounter',
#   'know'],
#  'suspect': ['believe guilty',
#   'guess',
#   'think probable',
#   'consider',
#   'assume',
#   'think of',
#   'suspicious',
#   'question',
#   'mistrust',
#   'think guilty',
#   'consider potentially guilty',
#   'feel',
#   'wonder about',
#   'reckon',
#   'expect',
#   'presume',
#   'imagine',
#   'postulate',
#   'believe',
#   'think',
#   'surmise'],
#  'take': ['think about',
#   'consider',
#   'experiment in their roles',
#   'accept',
#   'engage for',
#   'establish itself',
#   'happen',
#   'occur',
#   'start',
#   'pick up',
#   'occupy',
#   'include',
#   'be',
#   'begin',
#   'run',
#   'risk',
#   'get',
#   'grow',
#   'last',
#   'assume',
#   'gather',
#   'tolerate',
#   'collect',
#   'grasp',
#   'undergo'],
#  'tap': ['draw on',
#   'move',
#   'take advantage of',
#   'exploit',
#   'rap',
#   'touch',
#   'establish',
#   'milk',
#   'select',
#   'use',
#   'pat',
#   'extract',
#   'mark',
#   'commission',
#   'appeal to',
#   'recommend',
#   'strike',
#   'approach',
#   'choose',
#   'draw',
#   'draw upon',
#   'hit',
#   'utilise',
#   'beat',
#   'ask',
#   'syphon',
#   'appoint',
#   'knock',
#   'drum',
#   'contact'],
#  'tell': ['let me know',
#   'explain to',
#   'inform',
#   'said to',
#   'convey to',
#   'describe',
#   'communicate',
#   'impart',
#   'say to',
#   'assure',
#   'instruct',
#   'explain',
#   'notify',
#   'inform me of',
#   'recount',
#   'order',
#   'narrate'],
#  'tender': ['sympathetic',
#   'affectionate',
#   'kind',
#   'fond',
#   'sore',
#   'sensitive',
#   'great',
#   'young',
#   'early',
#   'gentle',
#   'delicate',
#   'immature',
#   'soft',
#   'inexperienced',
#   'painful',
#   'loving'],
#  'terrible': ['dreadful',
#   'atrocious',
#   'horrific',
#   'terrifying',
#   'poignant',
#   'deplorable',
#   'formidable',
#   'bad',
#   'appalling',
#   'abhorrent',
#   'severe',
#   'unpleasant',
#   'negative',
#   'horrible',
#   'awful',
#   'shocking',
#   'horrifying',
#   'frightening',
#   'fearsome',
#   'very bad'],
#  'test': ['exam',
#   'scan',
#   'evaluation',
#   'analysis',
#   'trial',
#   'examination',
#   'assessment',
#   'check'],
#  'therefore': ['as a result',
#   'thus',
#   'accordingly',
#   'so',
#   'hence',
#   'consequently'],
#  'think': ['reckon',
#   'guess',
#   'be of the opinion',
#   'consider',
#   'contemplate',
#   'feel',
#   'anticipate',
#   'imagine',
#   'analyse',
#   'assume',
#   'reason',
#   'suspect',
#   'expect',
#   'recommend',
#   'suppose',
#   'believe'],
#  'throw': ['propel',
#   'toss',
#   'hurl',
#   'focus',
#   'bring',
#   'ask of',
#   'pitch',
#   'fling',
#   'fire',
#   'deliver',
#   'punch',
#   'expose to',
#   'demand',
#   'ask',
#   'direct at',
#   'shoot',
#   'put',
#   'chuck',
#   'project',
#   'cast',
#   'place',
#   'discard'],
#  'thus': ['in this manner',
#   'this',
#   'there',
#   'accordingly',
#   'so',
#   'therefore',
#   'hence',
#   'consequently',
#   'in this way'],
#  'tight': ['secure',
#   'high-strung',
#   'stretched',
#   'uncomfortable',
#   'scarce',
#   'close',
#   'constricted',
#   'close to',
#   'pressured',
#   'restricted',
#   'pressurised',
#   'on top of',
#   'low',
#   'firmly',
#   'too small',
#   'close-fitting',
#   'close by',
#   'constricting',
#   'compressed',
#   'closely',
#   'securely',
#   'near',
#   'cramped',
#   'sparse',
#   'small',
#   'not easily available'],
#  'time': ['chance',
#   'allocation',
#   'instant',
#   'point',
#   'the Victorian period',
#   'age',
#   'interval',
#   'space',
#   'period',
#   'epoch',
#   'juncture',
#   'instance',
#   'moment',
#   'occasionally',
#   'deadline',
#   'era',
#   'occasion',
#   'a chance',
#   'opportunity',
#   'day',
#   'allotment'],
#  'touch': ['consider',
#   'feel',
#   'alight',
#   'get involved with',
#   'take on',
#   'influence',
#   'accept',
#   'stroke',
#   'skim',
#   'brush',
#   'undertake',
#   'skim over',
#   'come together',
#   'in contact with',
#   'come together with',
#   'talk about',
#   'contact',
#   'finger',
#   'influenced by',
#   'stir',
#   'do',
#   'move',
#   'handle',
#   'infect',
#   'speak about',
#   'reach',
#   'mention',
#   'make contact with',
#   'meet',
#   'affect',
#   'come into contact with',
#   'on',
#   'study',
#   'come in contact with',
#   'lean against',
#   'deal with',
#   'address slightly',
#   'affected by',
#   'get to',
#   'tinge',
#   'refer to'],
#  'tremendous': ['huge',
#   'great',
#   'marvellous',
#   'enormous',
#   'terrible',
#   'terrific',
#   'extraordinary',
#   'wonderful',
#   'vast'],
#  'true': ['real',
#   'right',
#   'verified',
#   'accurate',
#   'unquestionable',
#   'actual',
#   'truth',
#   'genuine',
#   'factual',
#   'correct',
#   'fact'],
#  'truly': ['truthfully',
#   'absolutely',
#   'undoubtedly',
#   'strictly',
#   'definitely',
#   'actually',
#   'unequivocally',
#   'unquestionably',
#   'honestly',
#   'fully',
#   'in truth',
#   'perfectly',
#   'really',
#   'genuinely'],
#  'vital': ['necessary',
#   'integral',
#   'indispensable',
#   'crucial',
#   'critical',
#   'fundamental',
#   'requisite',
#   'essential',
#   'important'],
#  'way': ['fashion',
#   'some',
#   'manner',
#   'aspect',
#   'sense',
#   'incidentally',
#   'respect',
#   'technique',
#   'passage',
#   'what the result would be',
#   'how',
#   'method',
#   'direction',
#   'means',
#   'far',
#   'practice',
#   'journey',
#   'while on the subject',
#   'by',
#   'characteristic',
#   'route',
#   'so'],
#  'well': ['and',
#   'indeed',
#   'successfully',
#   'excellently',
#   'including',
#   'good luck',
#   'carefully',
#   'long',
#   'much',
#   'in plenty of time',
#   'nice',
#   'then',
#   'healthily',
#   'in addition to',
#   'sufficient',
#   'along with',
#   'properly',
#   'satisfactorily',
#   'with',
#   'efficiently',
#   'bon voyage',
#   'safely',
#   'so',
#   'goodbye',
#   'in good health'],
#  'wild': ['crazy',
#   'its natural environment',
#   'wilderness',
#   'striking',
#   'chaotic',
#   'non-captive',
#   'undisciplined',
#   'huge',
#   'incredible',
#   'outside',
#   'amazing',
#   'animal',
#   'untamed animal',
#   'non-domestic',
#   'reckless',
#   'undomesticated',
#   'garish',
#   'unbelievable',
#   'free',
#   'coloured',
#   'dramatic',
#   'uninhabited land',
#   'unrestrained',
#   'extreme',
#   'patterned',
#   'untamed',
#   'natural',
#   'feral',
#   'irregular',
#   'unpredictable',
#   'uncultivated land',
#   'out of captivity'],
#  'wind': ['blast',
#   'vagary',
#   'air current',
#   'gust',
#   'gas',
#   'flatulence',
#   'breeze',
#   'current',
#   'fart',
#   'wind power',
#   'air flow',
#   'natural air movement',
#   'air',
#   'whirlwind'],
#  'work': ['function',
#   'task',
#   'collaborate',
#   'engage',
#   'be employed',
#   'move',
#   'look at',
#   'be occupied',
#   'research',
#   'employ',
#   'investigate',
#   'labour',
#   'act',
#   'toil',
#   'participate',
#   'undertake employment',
#   'cooperate',
#   'look into',
#   'operate'],
#  'worldwide': ['total', 'international', 'universal', 'global'],
#  'worthy': ['satisfactory',
#   'good',
#   'suitable',
#   'worthwhile',
#   'deserved',
#   'charitable',
#   'admirable',
#   'acceptable',
#   'beneficial',
#   'befitting',
#   'respectable',
#   'fitting',
#   'reputable',
#   'laudable',
#   'deserving',
#   'excellent',
#   'righteous',
#   'commendable',
#   'creditable',
#   'trusted',
#   'honourable'],
#  'yard': ['lawn',
#   'depot',
#   'garden',
#   'area',
#   'ground',
#   'work area',
#   'metre',
#   'garden ',
#   'enclosure',
#   'courtyard',
#   'several feet',
#   'terrace',
#   'lot',
#   'cul de sac',
#   'property',
#   'pn',
#   'sixty feet',
#   'patio',
#   'playground'],
#  'yet': ['thus far',
#   'in spite of that',
#   'lately',
#   'nevertheless',
#   'up to now',
#   'however',
#   'but',
#   'hitherto',
#   'despite this',
#   'to date',
#   'so far',
#   'although',
#   'not arrived',
#   'already',
#   'until now',
#   'are still to happen',
#   'still',
#   'before']}
