# %%
import numpy as np

from scipy.stats import pearsonr
from scipy.stats import spearmanr
from sklearn.metrics.pairwise import cosine_similarity
from scipy import spatial
from scipy import stats

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.nn.functional as F
torch.manual_seed(1)

import time
import datetime

from collections import defaultdict
from collections import Counter

from random import randint
import pickle

# %%
import nltk
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))

# %%
min_count = 2
threshold_for_subsampling = 0.00001 #recommended in Mikolov 2013
neg_context_k = 5 #negative samples
embedding_dim = 100
batch_size = 50
epochs = 10
lr = 0.01
window_size = 5 #dynamic given this value

#do we include punctuation marks?
#what to do about stop words, function words?
#what to do about infrequent words?
#what to do about numbers?
#what should be the output? which candidates should be selected?
#we removed \n
#what to do for word embedding initialization
# Improving Distributional Similarity with Lessons Learned fromWord Embeddings
# Omer Levy Yoav Goldberg Ido Dagan Computer

# %%
dataset = 'wa/dev.en'

#read the files
with open(dataset) as f:
    sentences = [l.strip() for l in f.readlines()]

#get all the tokens from the corpus

tokens_list = []
sentence_list = []
for s in sentences:
    split_sent = s.split()
    sentence = []
    for w in split_sent:
        
        tokens_list.append(w)
        sentence.append(w)
#         #filter stopwords
#         if w not in stopwords:
#             tokens_list.append(w)
#             sentence.append(w)
    
    sentence_list.append(sentence)
    
tokens = list(sorted(set(tokens_list)))
print('Vocabulary size', len(tokens))

count_tokens = Counter(tokens_list)

#words appearing fewer than this are not considered words or contexts
#subsample frequent words

temp_sentence_list = []

for s in range(len(sentence_list)):
    temp_sentence_list.append(sentence_list[s])

#Find the infrequent words
for s in range(len(temp_sentence_list)):
    for w in range(len(temp_sentence_list[s])):
        word = temp_sentence_list[s][w]
        if count_tokens[word] < min_count:
            sentence_list[s][w] = '<unk>'
            
            #remove the infrequent words from tokens
            tokens.remove(word)

#we prune rare words altogether

#tokens.append('<unk>')
vocab_size = len(tokens)
print('After rare word pruning', vocab_size)
#remove the infrequent words from the sentences
for s in sentence_list:
    s[:] = [w for w in s if w != '<unk>']

flat_token_list = []

for s in sentence_list:
    for w in s:
        flat_token_list.append(w)
# Out:
# Vocabulary size 322
# After rare word pruning 84

# %%
subsample_probs = defaultdict(float) 

count_words = Counter(flat_token_list)
print(count_words)
print(sum(count_words.values()))

for t in count_words:
    
    #Distributed Representations of Words and Phrases and their Compositionality
    #Mikolov 2013
    #p = 1 - sqrt(t/f)
    subsample_probs[t] = 1 - np.sqrt(threshold_for_subsampling/(count_words[t]/len(flat_sentence_list)))
    
temp_sentence_list = []

for s in range(len(sentence_list)):
    temp_sentence_list.append(sentence_list[s])

subsampled_sentence_list = []

#Prune frequent words
for s in range(len(temp_sentence_list)):
    sent = []
    for w in range(len(temp_sentence_list[s])):
        
        word = temp_sentence_list[s][w]
        word_prob = subsample_probs[word]
        
        rand_prob = np.random.rand(1)[0]
       
        if rand_prob < word_prob:
            #keep word
            sent.append(temp_sentence_list[s][w])
    
    subsampled_sentence_list.append(sent)
# Out:
# Counter({'.': 34, 'the': 33, 'to': 23, ',': 17, 'of': 14, 'in': 14, 'and': 13, 'that': 12, 'for': 11, 'it': 11, 'we': 11, 'a': 10, 'have': 9, 'is': 7, 'they': 7, 'be': 7, 'are': 6, 'I': 6, 'as': 6, 'very': 5, 'not': 5, 'our': 5, 'been': 5, 'this': 5, '$': 4, 'do': 4, 'what': 4, 'them': 3, 'which': 3, 'people': 3, 'on': 3, 'by': 3, 'one': 3, 'does': 3, 'Bill': 3, '-': 3, 'has': 3, 'there': 3, 'public': 3, 'or': 3, 'at': 3, 'however': 3, 'would': 3, 'want': 3, 'no': 3, 'will': 3, 'Mr.': 3, 'women': 3, 'complex': 2, 'whole': 2, 'most': 2, 'today': 2, 'who': 2, 'effective': 2, 'so': 2, 'let': 2, 'think': 2, 'should': 2, 'look': 2, 'cost': 2, 'some': 2, 'given': 2, 'see': 2, 'up': 2, 'say': 2, 'than': 2, 'programs': 2, 'within': 2, 'country': 2, 'support': 2, '?': 2, 'make': 2, 'Prime': 2, 'Minister': 2, 'need': 2, 'action': 2, 'under': 2, 'Speaker': 2, 'pretends': 2, 'employment': 2, 'equity': 2, 'job': 2, 'growers': 2, 'begin': 2})
# 423

# %%
pickle.dump(subsampled_sentence_list, open('subsampled_dataset.p', 'wb'))

# %%
subsampled_sentence_list = pickle.load(open('subsampled_dataset.p', 'rb'))

# %%
flat_subsampled_token_list = []

for s in subsampled_sentence_list:
    for w in s:
        flat_subsampled_token_list.append(w)

unigram_counts = Counter(flat_subsampled_token_list)

unigram_probs = defaultdict(float) 

for t in unigram_counts:
    unigram_probs[t] = unigram_counts[t]/len(flat_subsampled_token_list)

pickle.dump(unigram_probs, open('unigram_probs.p', 'wb'))

# %%
unigram_probs = pickle.load(open('unigram_probs.p', 'rb'))

# %%
def sampled_window(sentence, central_word_index, window_size):
    
    #implicit weighing of the context words
    #dynamic context window size for each word
    dynamic_window_size = randint(1,window_size)
    
    #dws = 2, i-2,i-1,i+1,i+2
    
    pairs = []
    word = sentence[central_word_index]
    for w in range(1,dynamic_window_size+1):
        
        left_cont = central_word_index - w
        right_cont = central_word_index + w
        
        #find the window words to the left and right
        #add as pair if they are inside sentence boundaries
        
        if left_cont > -1:
            pairs.append((word, sentence[left_cont]))
        
        if right_cont < len(sentence):
            pairs.append((word, sentence[right_cont]))
        
    return pairs

# %%
neg_sample_probs = defaultdict(float)

neg_normalizer = 0.0

for t in unigram_counts:
    neg_sample_probs[t] = np.power(unigram_counts[t], 0.75)
    neg_normalizer += neg_sample_probs[t]
    

for n in neg_sample_probs:
    neg_sample_probs[n] = neg_sample_probs[n] / neg_normalizer

# %%
#à la Mikolov
#table to pick negative context words
#fill the table with each word, count = negsampling prob*table size
neg_table_size = 10000000

unigram_table = np.empty(neg_table_size, dtype=object)
i = 0

for n in neg_sample_probs:
    count = int(neg_sample_probs[n] * neg_table_size)
    
    for c in range(count):
        unigram_table[i] = n
        
        i += 1
    
unigram_table = unigram_table[unigram_table != np.array(None)]
np.random.shuffle(unigram_table)
print(i)
print(len(unigram_table))
print(unigram_table[0:10])
# Out:
# 9999973
# 9999973
# ['of' 'the' 'should' 'to' 'as' 'what' 'within' 'public' 'would' 'it']

# %%
def pick_neg_context(table, k):
    
    neg_samples = []
    
    for i in range(k):
        
        r = randint(0,len(table)-1)
        neg_samples.append(table[r])
        
    return neg_samples

# %%
pos_context_pairs = []
neg_context_samples = []

for sentence in sentence_list:
    for w in range(len(sentence)):
        pos_context_pairs.extend(sampled_window(sentence, w, window_size))
        
        neg_context_samples.append((sentence[w], pick_neg_context(unigram_table, neg_context_k)))

pickle.dump(pos_context_pairs, open('pos_context_pairs.p', 'wb'))
pickle.dump(neg_context_samples, open('neg_context_samples.p', 'wb'))

# %%
pos_context_pairs = pickle.load(open('pos_context_pairs.p', 'rb'))
neg_context_samples = pickle.load(open('neg_context_samples.p', 'rb'))

# %%
pos_context_pairs
# Out:
# [('of', 'them'),
#  ('of', 'is'),
#  ('of', 'very'),
#  ('of', 'complex'),
#  ('them', 'of'),
#  ('them', 'is'),
#  ('is', 'them'),
#  ('is', 'very'),
#  ('is', 'of'),
#  ('is', 'complex'),
#  ('is', ','),
#  ('is', 'the'),
#  ('very', 'is'),
#  ('very', 'complex'),
#  ('very', 'them'),
#  ('very', ','),
#  ('very', 'of'),
#  ('very', 'the'),
#  ('complex', 'very'),
#  ('complex', ','),
#  ('complex', 'is'),
#  ('complex', 'the'),
#  ('complex', 'them'),
#  ('complex', 'the'),
#  ('complex', 'of'),
#  ('complex', 'is'),
#  ('complex', 'complex'),
#  (',', 'complex'),
#  (',', 'the'),
#  (',', 'very'),
#  (',', 'the'),
#  (',', 'is'),
#  (',', 'is'),
#  ('the', ','),
#  ('the', 'the'),
#  ('the', 'complex'),
#  ('the', 'is'),
#  ('the', 'the'),
#  ('the', 'is'),
#  ('the', ','),
#  ('the', 'complex'),
#  ('is', 'the'),
#  ('is', 'complex'),
#  ('complex', 'is'),
#  ('complex', 'which'),
#  ('complex', 'the'),
#  ('complex', 'the'),
#  ('which', 'complex'),
#  ('which', 'the'),
#  ('which', 'is'),
#  ('which', 'whole'),
#  ('which', 'the'),
#  ('which', 'for'),
#  ('which', 'the'),
#  ('which', 'most'),
#  ('the', 'which'),
#  ('the', 'whole'),
#  ('the', 'complex'),
#  ('the', 'for'),
#  ('whole', 'the'),
#  ('whole', 'for'),
#  ('whole', 'which'),
#  ('whole', 'most'),
#  ('whole', 'complex'),
#  ('whole', 'people'),
#  ('whole', 'is'),
#  ('whole', '.'),
#  ('whole', 'the'),
#  ('for', 'whole'),
#  ('for', 'most'),
#  ('for', 'the'),
#  ('for', 'people'),
#  ('most', 'for'),
#  ('most', 'people'),
#  ('most', 'whole'),
#  ('most', '.'),
#  ('most', 'the'),
#  ('most', 'which'),
#  ('most', 'complex'),
#  ('people', 'most'),
#  ('people', '.'),
#  ('people', 'for'),
#  ('people', 'whole'),
#  ('people', 'the'),
#  ('people', 'which'),
#  ('.', 'people'),
#  ('.', 'most'),
#  ('.', 'for'),
#  ('.', 'whole'),
#  ('the', 'on'),
#  ('on', 'the'),
#  ('they', 'are'),
#  ('they', 'by'),
#  ('they', 'which'),
#  ('they', 'are'),
#  ('they', 'in'),
#  ('are', 'they'),
#  ('are', 'by'),
#  ('are', 'which'),
#  ('are', 'are'),
#  ('are', 'in'),
#  ('by', 'are'),
#  ('by', 'which'),
#  ('which', 'by'),
#  ('which', 'are'),
#  ('which', 'are'),
#  ('which', 'in'),
#  ('which', 'they'),
#  ('which', 'to'),
#  ('are', 'which'),
#  ('are', 'in'),
#  ('are', 'by'),
#  ('are', 'to'),
#  ('are', 'are'),
#  ('are', 'that'),
#  ('are', 'they'),
#  ('are', 'the'),
#  ('are', 'of'),
#  ('in', 'are'),
#  ('in', 'to'),
#  ('in', 'which'),
#  ('in', 'that'),
#  ('to', 'in'),
#  ('to', 'that'),
#  ('to', 'are'),
#  ('to', 'the'),
#  ('to', 'which'),
#  ('to', 'of'),
#  ('that', 'to'),
#  ('that', 'the'),
#  ('that', 'in'),
#  ('that', 'of'),
#  ('that', 'are'),
#  ('that', 'one'),
#  ('that', 'which'),
#  ('that', 'does'),
#  ('the', 'that'),
#  ('the', 'of'),
#  ('the', 'to'),
#  ('the', 'one'),
#  ('the', 'in'),
#  ('the', 'does'),
#  ('of', 'the'),
#  ('of', 'one'),
#  ('of', 'that'),
#  ('of', 'does'),
#  ('of', 'to'),
#  ('of', 'not'),
#  ('one', 'of'),
#  ('one', 'does'),
#  ('one', 'the'),
#  ('one', 'not'),
#  ('one', 'that'),
#  ('one', 'that'),
#  ('one', 'to'),
#  ('one', 'of'),
#  ('does', 'one'),
#  ('does', 'not'),
#  ('does', 'of'),
#  ('does', 'that'),
#  ('does', 'the'),
#  ('does', 'of'),
#  ('does', 'that'),
#  ('does', '.'),
#  ('not', 'does'),
#  ('not', 'that'),
#  ('not', 'one'),
#  ('not', 'of'),
#  ('not', 'of'),
#  ('not', '.'),
#  ('not', 'the'),
#  ('not', 'that'),
#  ('that', 'not'),
#  ('that', 'of'),
#  ('that', 'does'),
#  ('that', '.'),
#  ('that', 'one'),
#  ('that', 'of'),
#  ('of', 'that'),
#  ('of', '.'),
#  ('of', 'not'),
#  ('.', 'of'),
#  ('.', 'that'),
#  ('.', 'not'),
#  ('it', 'the'),
#  ('it', 'and'),
#  ('it', 'of'),
#  ('the', 'it'),
#  ('the', 'and'),
#  ('the', 'of'),
#  ('and', 'the'),
#  ('and', 'of'),
#  ('and', 'it'),
#  ('and', 'on'),
#  ('and', 'our'),
#  ('and', 'for'),
#  ('and', 'and'),
#  ('of', 'and'),
#  ('of', 'on'),
#  ('of', 'the'),
#  ('of', 'our'),
#  ('of', 'it'),
#  ('of', 'for'),
#  ('on', 'of'),
#  ('on', 'our'),
#  ('on', 'and'),
#  ('on', 'for'),
#  ('our', 'on'),
#  ('our', 'for'),
#  ('for', 'our'),
#  ('for', 'and'),
#  ('for', 'on'),
#  ('for', '.'),
#  ('for', 'of'),
#  ('and', 'for'),
#  ('and', '.'),
#  ('and', 'our'),
#  ('and', 'on'),
#  ('and', 'of'),
#  ('and', 'and'),
#  ('.', 'and'),
#  ('.', 'for'),
#  ('.', 'our'),
#  ('the', 'in'),
#  ('in', 'the'),
#  ('in', 'which'),
#  ('in', 'Bill'),
#  ('in', '-'),
#  ('which', 'in'),
#  ('which', 'Bill'),
#  ('which', 'the'),
#  ('which', '-'),
#  ('which', 'has'),
#  ('which', 'been'),
#  ('Bill', 'which'),
#  ('Bill', '-'),
#  ('Bill', 'in'),
#  ('Bill', 'has'),
#  ('-', 'Bill'),
#  ('-', 'has'),
#  ('-', 'which'),
#  ('-', 'been'),
#  ('has', '-'),
#  ('has', 'been'),
#  ('has', 'Bill'),
#  ('has', 'today'),
#  ('been', 'has'),
#  ('been', 'today'),
#  ('been', '-'),
#  ('been', 'the'),
#  ('been', 'Bill'),
#  ('been', 'that'),
#  ('been', 'which'),
#  ('been', 'the'),
#  ('today', 'been'),
#  ('today', 'the'),
#  ('today', 'has'),
#  ('today', 'that'),
#  ('today', '-'),
#  ('today', 'the'),
#  ('today', 'Bill'),
#  ('today', 'are'),
#  ('today', 'which'),
#  ('today', 'and'),
#  ('the', 'today'),
#  ('the', 'that'),
#  ('the', 'been'),
#  ('the', 'the'),
#  ('that', 'the'),
#  ('that', 'the'),
#  ('that', 'today'),
#  ('that', 'are'),
#  ('that', 'been'),
#  ('that', 'and'),
#  ('that', 'has'),
#  ('that', '.'),
#  ('the', 'that'),
#  ('the', 'are'),
#  ('the', 'the'),
#  ('the', 'and'),
#  ('the', 'today'),
#  ('the', '.'),
#  ('the', 'been'),
#  ('are', 'the'),
#  ('are', 'and'),
#  ('are', 'that'),
#  ('are', '.'),
#  ('are', 'the'),
#  ('are', 'today'),
#  ('are', 'been'),
#  ('and', 'are'),
#  ('and', '.'),
#  ('and', 'the'),
#  ('and', 'that'),
#  ('and', 'the'),
#  ('.', 'and'),
#  ('.', 'are'),
#  ('.', 'the'),
#  ('.', 'that'),
#  ('I', 'a'),
#  ('I', 'who'),
#  ('I', 'to'),
#  ('a', 'I'),
#  ('a', 'who'),
#  ('a', 'to'),
#  ('a', 'be'),
#  ('who', 'a'),
#  ('who', 'to'),
#  ('who', 'I'),
#  ('who', 'be'),
#  ('to', 'who'),
#  ('to', 'be'),
#  ('to', 'a'),
#  ('to', 'there'),
#  ('to', 'I'),
#  ('to', '.'),
#  ('be', 'to'),
#  ('be', 'there'),
#  ('be', 'who'),
#  ('be', '.'),
#  ('there', 'be'),
#  ('there', '.'),
#  ('there', 'to'),
#  ('there', 'who'),
#  ('.', 'there'),
#  ('.', 'be'),
#  ('.', 'to'),
#  ('.', 'who'),
#  ('.', 'a'),
#  ('the', 'of'),
#  ('the', 'the'),
#  ('the', 'by'),
#  ('the', 'of'),
#  ('of', 'the'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'by'),
#  ('the', 'the'),
#  ('the', 'of'),
#  ('the', 'the'),
#  ('the', 'on'),
#  ('the', ','),
#  ('by', 'the'),
#  ('by', 'of'),
#  ('by', 'of'),
#  ('by', 'the'),
#  ('by', 'the'),
#  ('by', 'on'),
#  ('by', ','),
#  ('by', 'has'),
#  ('of', 'by'),
#  ('of', 'the'),
#  ('of', 'the'),
#  ('of', 'on'),
#  ('of', 'of'),
#  ('of', ','),
#  ('of', 'the'),
#  ('of', 'has'),
#  ('the', 'of'),
#  ('the', 'on'),
#  ('the', 'by'),
#  ('the', ','),
#  ('the', 'the'),
#  ('the', 'has'),
#  ('the', 'of'),
#  ('the', 'been'),
#  ('on', 'the'),
#  ('on', ','),
#  ('on', 'of'),
#  ('on', 'has'),
#  ('on', 'by'),
#  ('on', 'been'),
#  ('on', 'the'),
#  ('on', '.'),
#  (',', 'on'),
#  (',', 'has'),
#  (',', 'the'),
#  (',', 'been'),
#  (',', 'of'),
#  (',', '.'),
#  (',', 'by'),
#  (',', 'the'),
#  ('has', ','),
#  ('has', 'been'),
#  ('has', 'on'),
#  ('has', '.'),
#  ('has', 'the'),
#  ('has', 'of'),
#  ('been', 'has'),
#  ('been', '.'),
#  ('been', ','),
#  ('been', 'on'),
#  ('been', 'the'),
#  ('been', 'of'),
#  ('.', 'been'),
#  ('.', 'has'),
#  ('.', ','),
#  ('I', 'have'),
#  ('I', 'the'),
#  ('have', 'I'),
#  ('have', 'the'),
#  ('the', 'have'),
#  ('the', 'as'),
#  ('the', 'I'),
#  ('the', 'of'),
#  ('the', ','),
#  ('as', 'the'),
#  ('as', 'of'),
#  ('as', 'have'),
#  ('as', ','),
#  ('of', 'as'),
#  ('of', ','),
#  (',', 'of'),
#  (',', 'effective'),
#  (',', 'as'),
#  (',', 'public'),
#  ('effective', ','),
#  ('effective', 'public'),
#  ('effective', 'of'),
#  ('effective', '.'),
#  ('public', 'effective'),
#  ('public', '.'),
#  ('public', ','),
#  ('public', 'of'),
#  ('public', 'as'),
#  ('.', 'public'),
#  ('.', 'effective'),
#  ('so', ','),
#  ('so', '$'),
#  ('so', 'have'),
#  ('so', 'been'),
#  (',', 'so'),
#  (',', '$'),
#  (',', 'have'),
#  (',', 'been'),
#  ('$', ','),
#  ('$', 'have'),
#  ('$', 'so'),
#  ('$', 'been'),
#  ('have', '$'),
#  ('have', 'been'),
#  ('have', ','),
#  ('have', 'by'),
#  ('been', 'have'),
#  ('been', 'by'),
#  ('been', '$'),
#  ('been', 'the'),
#  ('been', ','),
#  ('been', 'in'),
#  ('by', 'been'),
#  ('by', 'the'),
#  ('by', 'have'),
#  ('by', 'in'),
#  ('by', '$'),
#  ('by', 'for'),
#  ('by', ','),
#  ('by', 'or'),
#  ('the', 'by'),
#  ('the', 'in'),
#  ('the', 'been'),
#  ('the', 'for'),
#  ('the', 'have'),
#  ('the', 'or'),
#  ('in', 'the'),
#  ('in', 'for'),
#  ('in', 'by'),
#  ('in', 'or'),
#  ('in', 'been'),
#  ('in', 'public'),
#  ('in', 'have'),
#  ('in', '.'),
#  ('for', 'in'),
#  ('for', 'or'),
#  ('for', 'the'),
#  ('for', 'public'),
#  ('for', 'by'),
#  ('for', '.'),
#  ('for', 'been'),
#  ('for', 'have'),
#  ('or', 'for'),
#  ('or', 'public'),
#  ('or', 'in'),
#  ('or', '.'),
#  ('public', 'or'),
#  ('public', '.'),
#  ('public', 'for'),
#  ('.', 'public'),
#  ('.', 'or'),
#  ('.', 'for'),
#  ('.', 'in'),
#  ('let', '.'),
#  ('.', 'let'),
#  ('I', 'think'),
#  ('I', 'we'),
#  ('I', 'should'),
#  ('I', 'a'),
#  ('I', 'look'),
#  ('think', 'I'),
#  ('think', 'we'),
#  ('we', 'think'),
#  ('we', 'should'),
#  ('we', 'I'),
#  ('we', 'a'),
#  ('we', 'look'),
#  ('we', 'at'),
#  ('should', 'we'),
#  ('should', 'a'),
#  ('should', 'think'),
#  ('should', 'look'),
#  ('should', 'I'),
#  ('should', 'at'),
#  ('should', 'this'),
#  ('a', 'should'),
#  ('a', 'look'),
#  ('a', 'we'),
#  ('a', 'at'),
#  ('a', 'think'),
#  ('a', 'this'),
#  ('a', 'I'),
#  ('a', 'to'),
#  ('look', 'a'),
#  ('look', 'at'),
#  ('look', 'should'),
#  ('look', 'this'),
#  ('look', 'we'),
#  ('look', 'to'),
#  ('look', 'think'),
#  ('look', 'or'),
#  ('at', 'look'),
#  ('at', 'this'),
#  ('at', 'a'),
#  ('at', 'to'),
#  ('at', 'should'),
#  ('at', 'or'),
#  ('at', 'we'),
#  ('at', 'not'),
#  ('at', 'think'),
#  ('at', 'it'),
#  ('this', 'at'),
#  ('this', 'to'),
#  ('this', 'look'),
#  ('this', 'or'),
#  ('this', 'a'),
#  ('this', 'not'),
#  ('this', 'should'),
#  ('this', 'it'),
#  ('this', 'we'),
#  ('this', 'is'),
#  ('to', 'this'),
#  ('to', 'or'),
#  ('to', 'at'),
#  ('to', 'not'),
#  ('to', 'look'),
#  ('to', 'it'),
#  ('or', 'to'),
#  ('or', 'not'),
#  ('not', 'or'),
#  ('not', 'it'),
#  ('it', 'not'),
#  ('it', 'is'),
#  ('it', 'or'),
#  ('it', 'cost'),
#  ('it', 'to'),
#  ('it', 'effective'),
#  ('it', 'this'),
#  ('it', 'and'),
#  ('is', 'it'),
#  ('is', 'cost'),
#  ('is', 'not'),
#  ('is', 'effective'),
#  ('is', 'or'),
#  ('is', 'and'),
#  ('cost', 'is'),
#  ('cost', 'effective'),
#  ('cost', 'it'),
#  ('cost', 'and'),
#  ('cost', 'not'),
#  ('cost', 'in'),
#  ('cost', 'or'),
#  ('cost', 'the'),
#  ('effective', 'cost'),
#  ('effective', 'and'),
#  ('effective', 'is'),
#  ('effective', 'in'),
#  ('and', 'effective'),
#  ('and', 'in'),
#  ('in', 'and'),
#  ('in', 'the'),
#  ('in', 'effective'),
#  ('in', 'public'),
#  ('in', 'cost'),
#  ('in', '.'),
#  ('in', 'is'),
#  ('the', 'in'),
#  ('the', 'public'),
#  ('public', 'the'),
#  ('public', '.'),
#  ('public', 'in'),
#  ('public', 'and'),
#  ('public', 'effective'),
#  ('.', 'public'),
#  ('.', 'the'),
#  ('.', 'in'),
#  ('.', 'and'),
#  ('.', 'effective'),
#  ('however', ','),
#  (',', 'however'),
#  (',', 'that'),
#  (',', 'some'),
#  (',', 'very'),
#  (',', 'given'),
#  (',', 'the'),
#  ('that', ','),
#  ('that', 'some'),
#  ('that', 'however'),
#  ('that', 'very'),
#  ('that', 'given'),
#  ('some', 'that'),
#  ('some', 'very'),
#  ('some', ','),
#  ('some', 'given'),
#  ('some', 'however'),
#  ('some', 'the'),
#  ('very', 'some'),
#  ('very', 'given'),
#  ('very', 'that'),
#  ('very', 'the'),
#  ('very', ','),
#  ('very', '-'),
#  ('given', 'very'),
#  ('given', 'the'),
#  ('given', 'some'),
#  ('given', '-'),
#  ('the', 'given'),
#  ('the', '-'),
#  ('the', 'very'),
#  ('the', 'in'),
#  ('the', 'some'),
#  ('the', 'the'),
#  ('the', 'that'),
#  ('the', '.'),
#  ('the', ','),
#  ('-', 'the'),
#  ('-', 'in'),
#  ('-', 'given'),
#  ('-', 'the'),
#  ('-', 'very'),
#  ('-', '.'),
#  ('-', 'some'),
#  ('in', '-'),
#  ('in', 'the'),
#  ('in', 'the'),
#  ('in', '.'),
#  ('in', 'given'),
#  ('in', 'very'),
#  ('the', 'in'),
#  ('the', '.'),
#  ('the', '-'),
#  ('the', 'the'),
#  ('the', 'given'),
#  ('the', 'very'),
#  ('.', 'the'),
#  ('.', 'in'),
#  ('.', '-'),
#  ('we', 'see'),
#  ('we', 'the'),
#  ('we', 'up'),
#  ('see', 'we'),
#  ('see', 'the'),
#  ('the', 'see'),
#  ('the', 'up'),
#  ('the', 'we'),
#  ('the', '$'),
#  ('the', 'to'),
#  ('the', '$'),
#  ('up', 'the'),
#  ('up', '$'),
#  ('up', 'see'),
#  ('up', 'to'),
#  ('up', 'we'),
#  ('up', '$'),
#  ('up', '.'),
#  ('$', 'up'),
#  ('$', 'to'),
#  ('$', 'the'),
#  ('$', '$'),
#  ('$', 'see'),
#  ('$', '.'),
#  ('$', 'we'),
#  ('to', '$'),
#  ('to', '$'),
#  ('$', 'to'),
#  ('$', '.'),
#  ('$', '$'),
#  ('$', 'up'),
#  ('$', 'the'),
#  ('$', 'see'),
#  ('.', '$'),
#  ('.', 'to'),
#  ('.', '$'),
#  ('.', 'up'),
#  ('it', 'would'),
#  ('it', 'have'),
#  ('it', 'been'),
#  ('would', 'it'),
#  ('would', 'have'),
#  ('have', 'would'),
#  ('have', 'been'),
#  ('have', 'it'),
#  ('have', 'to'),
#  ('have', 'say'),
#  ('have', 'that'),
#  ('been', 'have'),
#  ('been', 'to'),
#  ('to', 'been'),
#  ('to', 'say'),
#  ('to', 'have'),
#  ('to', 'that'),
#  ('to', 'would'),
#  ('to', 'have'),
#  ('to', 'it'),
#  ('to', 'to'),
#  ('say', 'to'),
#  ('say', 'that'),
#  ('say', 'been'),
#  ('say', 'have'),
#  ('say', 'have'),
#  ('say', 'to'),
#  ('say', 'would'),
#  ('say', 'be'),
#  ('say', 'it'),
#  ('say', 'than'),
#  ('that', 'say'),
#  ('that', 'have'),
#  ('that', 'to'),
#  ('that', 'to'),
#  ('that', 'been'),
#  ('that', 'be'),
#  ('have', 'that'),
#  ('have', 'to'),
#  ('have', 'say'),
#  ('have', 'be'),
#  ('have', 'to'),
#  ('have', 'than'),
#  ('have', 'been'),
#  ('have', 'them'),
#  ('to', 'have'),
#  ('to', 'be'),
#  ('to', 'that'),
#  ('to', 'than'),
#  ('be', 'to'),
#  ('be', 'than'),
#  ('than', 'be'),
#  ('than', 'them'),
#  ('than', 'to'),
#  ('than', '.'),
#  ('than', 'have'),
#  ('than', 'that'),
#  ('them', 'than'),
#  ('them', '.'),
#  ('them', 'be'),
#  ('them', 'to'),
#  ('them', 'have'),
#  ('.', 'them'),
#  ('.', 'than'),
#  ('.', 'be'),
#  ('.', 'to'),
#  ('we', 'have'),
#  ('we', 'to'),
#  ('we', 'programs'),
#  ('we', 'for'),
#  ('we', 'within'),
#  ('have', 'we'),
#  ('have', 'to'),
#  ('have', 'programs'),
#  ('have', 'for'),
#  ('have', 'within'),
#  ('have', 'our'),
#  ('to', 'have'),
#  ('to', 'programs'),
#  ('to', 'we'),
#  ('to', 'for'),
#  ('to', 'within'),
#  ('to', 'our'),
#  ('to', '.'),
#  ('programs', 'to'),
#  ('programs', 'for'),
#  ('programs', 'have'),
#  ('programs', 'within'),
#  ('programs', 'we'),
#  ('programs', 'our'),
#  ('programs', '.'),
#  ('for', 'programs'),
#  ('for', 'within'),
#  ('within', 'for'),
#  ('within', 'our'),
#  ('within', 'programs'),
#  ('within', '.'),
#  ('within', 'to'),
#  ('within', 'have'),
#  ('within', 'we'),
#  ('our', 'within'),
#  ('our', '.'),
#  ('our', 'for'),
#  ('our', 'programs'),
#  ('our', 'to'),
#  ('our', 'have'),
#  ('.', 'our'),
#  ('.', 'within'),
#  ('.', 'for'),
#  ('.', 'programs'),
#  ('.', 'to'),
#  ('we', 'should'),
#  ('should', 'we'),
#  ('should', 'our'),
#  ('our', 'should'),
#  ('our', 'that'),
#  ('our', 'we'),
#  ('our', 'we'),
#  ('that', 'our'),
#  ('that', 'we'),
#  ('that', 'should'),
#  ('that', 'do'),
#  ('that', 'we'),
#  ('that', 'have'),
#  ('that', 'a'),
#  ('we', 'that'),
#  ('we', 'do'),
#  ('do', 'we'),
#  ('do', 'have'),
#  ('do', 'that'),
#  ('do', 'a'),
#  ('do', 'our'),
#  ('do', 'very'),
#  ('do', 'should'),
#  ('do', 'country'),
#  ('have', 'do'),
#  ('have', 'a'),
#  ('have', 'we'),
#  ('have', 'very'),
#  ('have', 'that'),
#  ('have', 'country'),
#  ('have', 'our'),
#  ('have', '.'),
#  ('have', 'should'),
#  ('a', 'have'),
#  ('a', 'very'),
#  ('a', 'do'),
#  ('a', 'country'),
#  ('a', 'we'),
#  ('a', '.'),
#  ('very', 'a'),
#  ('very', 'country'),
#  ('very', 'have'),
#  ('very', '.'),
#  ('very', 'do'),
#  ('very', 'we'),
#  ('very', 'that'),
#  ('country', 'very'),
#  ('country', '.'),
#  ('country', 'a'),
#  ('.', 'country'),
#  ('.', 'very'),
#  ('.', 'a'),
#  ('.', 'have'),
#  ('.', 'do'),
#  ('they', ','),
#  (',', 'they'),
#  (',', 'of'),
#  ('of', ','),
#  ('of', ','),
#  (',', 'of'),
#  (',', 'support'),
#  (',', ','),
#  (',', 'the'),
#  ('support', ','),
#  ('support', 'the'),
#  ('support', 'of'),
#  ('support', 'country'),
#  ('support', ','),
#  ('support', '.'),
#  ('support', 'they'),
#  ('the', 'support'),
#  ('the', 'country'),
#  ('the', ','),
#  ('the', '.'),
#  ('the', 'of'),
#  ('the', ','),
#  ('country', 'the'),
#  ('country', '.'),
#  ('country', 'support'),
#  ('country', ','),
#  ('country', 'of'),
#  ('.', 'country'),
#  ('.', 'the'),
#  ('.', 'support'),
#  ('.', ','),
#  ('.', 'of'),
#  ('what', 'does'),
#  ('does', 'what'),
#  ('does', 'it'),
#  ('does', 'for'),
#  ('does', 'a'),
#  ('does', '$'),
#  ('it', 'does'),
#  ('it', 'for'),
#  ('it', 'what'),
#  ('it', 'a'),
#  ('it', '$'),
#  ('it', 'the'),
#  ('it', 'and'),
#  ('for', 'it'),
#  ('for', 'a'),
#  ('for', 'does'),
#  ('for', '$'),
#  ('for', 'what'),
#  ('for', 'the'),
#  ('a', 'for'),
#  ('a', '$'),
#  ('a', 'it'),
#  ('a', 'the'),
#  ('$', 'a'),
#  ('$', 'the'),
#  ('$', 'for'),
#  ('$', 'and'),
#  ('$', 'it'),
#  ('$', '?'),
#  ('$', 'does'),
#  ('$', 'what'),
#  ('the', '$'),
#  ('the', 'and'),
#  ('the', 'a'),
#  ('the', '?'),
#  ('the', 'for'),
#  ('the', 'it'),
#  ('and', 'the'),
#  ('and', '?'),
#  ('and', '$'),
#  ('?', 'and'),
#  ('?', 'the'),
#  ('?', '$'),
#  ('?', 'a'),
#  ('I', 'want'),
#  ('I', 'to'),
#  ('I', 'make'),
#  ('I', 'it'),
#  ('I', 'that'),
#  ('want', 'I'),
#  ('want', 'to'),
#  ('want', 'make'),
#  ('want', 'it'),
#  ('to', 'want'),
#  ('to', 'make'),
#  ('make', 'to'),
#  ('make', 'it'),
#  ('make', 'want'),
#  ('make', 'that'),
#  ('it', 'make'),
#  ('it', 'that'),
#  ('it', 'to'),
#  ('it', 'we'),
#  ('it', 'want'),
#  ('it', 'have'),
#  ('it', 'I'),
#  ('it', 'to'),
#  ('it', 'let'),
#  ('that', 'it'),
#  ('that', 'we'),
#  ('we', 'that'),
#  ('we', 'have'),
#  ('we', 'it'),
#  ('we', 'to'),
#  ('we', 'make'),
#  ('we', 'let'),
#  ('we', 'to'),
#  ('we', 'this'),
#  ('have', 'we'),
#  ('have', 'to'),
#  ('have', 'that'),
#  ('have', 'let'),
#  ('have', 'it'),
#  ('have', 'this'),
#  ('have', 'make'),
#  ('have', 'to'),
#  ('have', 'to'),
#  ('have', 'a'),
#  ('to', 'have'),
#  ('to', 'let'),
#  ('to', 'we'),
#  ('to', 'this'),
#  ('to', 'that'),
#  ('to', 'to'),
#  ('let', 'to'),
#  ('let', 'this'),
#  ('let', 'have'),
#  ('let', 'to'),
#  ('let', 'we'),
#  ('let', 'a'),
#  ('this', 'let'),
#  ('this', 'to'),
#  ...]

# %%
neg_context_samples
# Out:
# [('of', [',', 'to', 'to', 'need', 'think']),
#  ('them', ['this', 'the', 'do', 'has', 'do']),
#  ('is', ['pretends', 'of', 'it', '$', 'given']),
#  ('very', ['a', 'and', 'we', 'the', 'that']),
#  ('complex', ['one', 'under', 'we', '$', 'we']),
#  (',', ['as', '.', 'growers', '?', 'make']),
#  ('the', ['some', 'one', 'we', 'within', 'country']),
#  ('the', ['they', 'at', 'women', 'in', 'the']),
#  ('is', ['will', 'it', 'has', 'is', 'let']),
#  ('complex', ['.', '.', 'does', 'women', 'let']),
#  ('which', ['say', 'the', '-', 'to', 'is']),
#  ('the', ['has', 'Minister', 'it', 'within', 'will']),
#  ('whole', ['the', 'in', 'very', 'of', 'country']),
#  ('for', ['Mr.', 'in', 'a', 'effective', 'and']),
#  ('most', ['it', ',', 'Prime', 'however', 'do']),
#  ('people', ['should', 'what', 'Mr.', 'Prime', 'there']),
#  ('.', ['.', 'up', 'a', 'which', 'they']),
#  ('the', ['it', 'that', 'job', 'have', 'the']),
#  ('on', ['the', 'been', 'be', 'for', 'people']),
#  ('they', ['is', 'have', 'Minister', 'what', 'in']),
#  ('are', ['we', 'of', 'they', 'job', 'which']),
#  ('by', ['whole', 'Speaker', '?', 'support', 'they']),
#  ('which', ['we', 'Bill', '$', 'a', 'they']),
#  ('are', ['equity', 'whole', 'are', 'one', 'however']),
#  ('in', ['however', 'do', 'Prime', 'given', 'very']),
#  ('to', ['I', 'the', 'the', 'of', ',']),
#  ('that', ['this', 'of', 'no', 'equity', 'there']),
#  ('the', ['I', 'at', 'say', 'think', 'have']),
#  ('of', ['will', 'we', '.', 'our', 'and']),
#  ('one', ['the', 'of', 'effective', 'which', 'women']),
#  ('does', ['women', '?', '.', 'who', 'a']),
#  ('not', ['has', 'of', 'people', 'be', 'action']),
#  ('that', ['I', ',', 'whole', 'been', 'is']),
#  ('of', ['in', 'or', '.', 'to', 'the']),
#  ('.', ['country', 'a', 'pretends', 'employment', 'our']),
#  ('it', ['or', 'of', 'our', '.', 'not']),
#  ('the', ['.', 'are', 'of', 'whole', 'up']),
#  ('and', ['up', 'the', 'has', 'job', 'they']),
#  ('of', [',', 'to', 'is', '.', 'so']),
#  ('on', ['job', 'pretends', 'have', 'of', 'some']),
#  ('our', ['is', 'of', 'make', 'and', '.']),
#  ('for', ['we', 'not', 'what', 'some', 'some']),
#  ('and', ['the', 'be', 'today', 'begin', 'them']),
#  ('.', ['$', 'not', 'is', 'have', 'our']),
#  ('the', ['.', 'in', 'them', 'them', 'is']),
#  ('in', ['the', 'the', 'of', '$', 'there']),
#  ('which', ['people', 'for', ',', 'would', 'Speaker']),
#  ('Bill', ['have', 'to', 'and', 'it', 'think']),
#  ('-', ['a', 'and', 'a', 'on', 'as']),
#  ('has', ['does', 'what', 'one', 'job', 'is']),
#  ('been', ['and', 'in', 'action', 'programs', 'of']),
#  ('today', ['the', 'one', 'who', 'who', 'in']),
#  ('the', ['Mr.', 'within', 'that', 'them', 'there']),
#  ('that', ['want', 'does', 'very', 'of', 'a']),
#  ('the', ['a', 'by', 'as', 'to', 'by']),
#  ('are', ['one', '-', 'say', 'for', 'Minister']),
#  ('and', ['for', '.', 'would', 'been', 'is']),
#  ('.', ['are', 'I', '-', 'that', 'programs']),
#  ('I', ['that', ',', 'Mr.', '-', 'to']),
#  ('a', ['which', 'I', 'of', 'some', 'the']),
#  ('who', ['of', '.', '-', 'than', 'for']),
#  ('to', ['very', 'support', '.', ',', 'whole']),
#  ('be', ['look', 'the', '.', 'it', 'of']),
#  ('there', ['do', '?', 'be', 'the', 'of']),
#  ('.', ['or', 'effective', 'to', 'there', 'the']),
#  ('the', ['cost', 'employment', 'there', 'up', 'make']),
#  ('of', ['Mr.', 'what', 'what', 'people', 'so']),
#  ('the', ['in', 'been', 'of', 'within', '.']),
#  ('by', ['it', 'as', 'we', 'see', ',']),
#  ('of', ['on', 'a', 'them', 'them', 'for']),
#  ('the', ['what', 'most', 'be', 'is', 'Bill']),
#  ('on', ['I', 'begin', 'I', 'for', 'a']),
#  (',', ['complex', 'to', ',', 'employment', 'of']),
#  ('has', ['be', 'no', 'today', 'we', 'one']),
#  ('been', ['the', 'to', ',', 'be', 'be']),
#  ('.', ['the', 'Minister', 'on', 'very', 'have']),
#  ('I', ['it', 'that', 'they', 'country', 'for']),
#  ('have', ['within', 'pretends', 'it', 'the', 'in']),
#  ('the', ['a', 'our', 'them', 'should', 'growers']),
#  ('as', ['of', 'what', 'they', 'our', '.']),
#  ('of', ['than', 'it', 'is', 'for', ',']),
#  (',', ['have', 'job', 'for', 'be', ',']),
#  ('effective', ['country', 'under', 'as', 'a', 'have']),
#  ('public', ['they', 'of', 'they', 'one', 'action']),
#  ('.', ['the', ',', 'to', 'most', 'by']),
#  ('so', ['on', 'a', 'not', ',', '.']),
#  (',', ['the', 'a', 'which', 'been', 'public']),
#  ('$', ['is', 'and', 'the', 'to', 'support']),
#  ('have', ['it', 'a', 'will', 'most', 'up']),
#  ('been', ['need', 'need', 'who', '.', 'that']),
#  ('by', ['a', 'and', 'say', '?', 'to']),
#  ('the', ['think', 'is', 'for', 'under', 'some']),
#  ('in', ['it', 'of', '.', 'the', '.']),
#  ('for', ['been', 'the', 'to', ',', 'for']),
#  ('or', ['what', 'job', 'in', 'public', 'a']),
#  ('public', ['whole', 'of', 'and', 'that', 'no']),
#  ('.', ['job', 'for', ',', 'is', 'which']),
#  ('let', ['the', 'for', 'there', 'of', 'make']),
#  ('.', ['make', '.', 'or', 'not', '.']),
#  ('I', ['the', 'are', 'want', 'will', 'whole']),
#  ('think', ['up', 'I', 'been', 'what', 'should']),
#  ('we', ['.', 'I', 'need', 'should', 'do']),
#  ('should', ['are', 'public', 'begin', '.', 'there']),
#  ('a', ['for', 'growers', 'are', 'see', 'Speaker']),
#  ('look', ['they', 'a', 'are', 'I', 'make']),
#  ('at', ['the', 'it', 'it', 'have', 'say']),
#  ('this', ['in', 'begin', 'at', 'to', ',']),
#  ('to', ['-', 'a', 'the', 'pretends', 'people']),
#  ('or', ['within', 'that', '.', 'the', 'them']),
#  ('not', ['to', 'I', 'one', 'the', 'within']),
#  ('it', ['is', 'for', 'complex', 'and', 'I']),
#  ('is', ['-', 'the', 'I', 'equity', 'within']),
#  ('cost', ['do', 'of', 'need', 'growers', 'effective']),
#  ('effective', ['they', '.', '.', 'who', 'up']),
#  ('and', ['very', 'not', 'this', 'up', '-']),
#  ('in', ['there', 'have', 'our', 'that', 'be']),
#  ('the', ['have', 'which', 'the', 'and', 'have']),
#  ('public', ['be', 'begin', 'in', 'is', 'equity']),
#  ('.', ['who', 'for', 'a', 'or', 'been']),
#  ('however', ['on', 'programs', 'be', 'have', 'up']),
#  (',', ['very', 'within', 'want', 'we', 'country']),
#  ('that', ['of', 'what', 'job', 'of', 'to']),
#  ('some', ['the', 'very', 'very', 'by', 'whole']),
#  ('very', ['we', 'women', 'to', ',', 'look']),
#  ('given', ['and', 'at', 'Minister', 'complex', 'have']),
#  ('the', ['which', 'action', 'most', 'it', 'see']),
#  ('-', ['the', ',', '.', 'a', 'that']),
#  ('in', ['them', '.', 'however', 'is', 'job']),
#  ('the', ['a', '?', '.', 'women', 'for']),
#  ('.', ['the', 'that', 'Minister', 'employment', 'whole']),
#  ('we', ['want', 'Bill', 'is', 'the', 'it']),
#  ('see', ['however', 'not', 'as', 'country', 'of']),
#  ('the', ['be', 'say', 'one', 'Speaker', 'a']),
#  ('up', ['in', 'the', 'will', 'be', 'by']),
#  ('$', ['I', 'do', '.', 'however', 'what']),
#  ('to', ['that', 'however', 'a', 'have', 'no']),
#  ('$', ['-', 'for', 'pretends', 'there', 'job']),
#  ('.', ['so', 'most', 'there', 'and', 'people']),
#  ('it', ['the', ',', 'given', 'been', 'and']),
#  ('would', ['whole', 'a', 'not', 'the', 'job']),
#  ('have', [',', ',', '?', 'a', 'to']),
#  ('been', ['by', 'would', 'make', 'the', 'should']),
#  ('to', ['Speaker', 'it', 'who', 'action', 'does']),
#  ('say', ['however', 'today', 'we', 'of', 'Bill']),
#  ('that', ['do', 'job', '.', 'for', 'have']),
#  ('have', ['given', 'country', '.', '.', 'we']),
#  ('to', ['growers', 'growers', 'our', '.', 'be']),
#  ('be', ['Prime', 'as', 'that', 'this', 'it']),
#  ('than', ['growers', 'there', 'so', 'what', 'make']),
#  ('them', ['who', 'one', 'for', 'not', 'has']),
#  ('.', ['job', 'cost', 'they', 'that', 'of']),
#  ('we', ['complex', 'as', 'them', '?', 'women']),
#  ('have', ['cost', 'to', 'a', 'no', 'they']),
#  ('to', ['think', 'to', 'of', 'them', 'it']),
#  ('programs', ['we', 'has', 'given', 'Minister', 'what']),
#  ('for', ['for', 'does', 'to', 'want', 'however']),
#  ('within', ['very', 'of', 'support', '.', '.']),
#  ('our', ['this', 'given', ',', 'this', 'should']),
#  ('.', ['the', 'action', 'job', 'which', 'say']),
#  ('we', ['Minister', 'we', 'is', 'a', 'for']),
#  ('should', ['today', ',', 'the', 'Bill', 'the']),
#  ('our', ['it', 'be', '$', 'of', 'to']),
#  ('that', ['have', 'they', 'let', 'in', 'to']),
#  ('we', ['than', 'and', 'as', 'at', 'one']),
#  ('do', ['given', 'which', 'does', '?', 'do']),
#  ('have', ['and', ',', 'let', 'this', 'and']),
#  ('a', ['been', 'the', 'I', 'and', 'by']),
#  ('very', ['has', 'look', 'this', 'be', 'of']),
#  ('country', ['today', 'there', 'it', 'will', 'have']),
#  ('.', ['the', 'of', 'need', 'make', 'of']),
#  ('they', ['want', '.', 'say', ',', 'been']),
#  (',', ['the', 'have', 'and', 'that', 'in']),
#  ('of', ['it', 'what', '.', 'a', 'be']),
#  (',', ['support', 'some', 'that', 'which', 'and']),
#  ('support', ['I', 'we', 'to', 'will', '.']),
#  ('the', ['to', 'of', 'action', 'to', 'it']),
#  ('country', ['them', 'in', 'see', 'has', 'that']),
#  ('.', ['and', 'what', 'Speaker', 'Bill', 'what']),
#  ('what', ['to', 'has', 'country', 'there', 'very']),
#  ('does', ['and', 'equity', 'have', 'up', '.']),
#  ('it', ['and', 'or', 'which', 'will', 'given']),
#  ('for', ['and', 'as', 'to', 'them', 'we']),
#  ('a', ['they', 'growers', 'it', 'have', 'not']),
#  ('$', ['up', 'as', 'growers', 'to', 'some']),
#  ('the', ['it', 'however', 'to', 'most', 'support']),
#  ('and', ['to', 'today', 'that', 'and', 'have']),
#  ('?', ['the', 'I', 'what', '?', 'in']),
#  ('I', ['today', 'they', 'so', 'are', 'I']),
#  ('want', ['.', 'the', 'not', 'look', 'of']),
#  ('to', ['job', 'under', 'there', 'of', 'effective']),
#  ('make', ['to', 'a', 'country', 'a', 'by']),
#  ('it', ['that', 'very', 'we', 'them', 'I']),
#  ('that', ['a', 'not', 'of', 'whole', 'to']),
#  ('we', ['are', 'today', ',', 'should', 'the']),
#  ('have', ['the', '.', 'as', 'growers', 'however']),
#  ('to', ['to', 'within', 'Mr.', 'it', 'in']),
#  ('let', ['.', 'our', 'as', 'as', 'of']),
#  ('this', ['to', 'women', 'begin', 'it', 'look']),
#  ('to', ['employment', 'there', 'Speaker', 'very', 'for']),
#  ('a', ['need', 'some', 'for', 'is', 'to']),
#  ('today', ['a', 'begin', 'say', 'a', 'action']),
#  ('.', ['they', ',', '.', 'do', 'complex']),
#  ('the', ['been', 'of', 'be', '$', 'it']),
#  ('Prime', ['growers', 'be', '-', 'job', 'have']),
#  ('Minister', ['I', 'they', 'be', 'public', 'to']),
#  ('and', ['and', 'the', 'most', 'that', 'for']),
#  ('the', ['in', 'want', 'think', 'at', '$']),
#  ('do', ['the', 'need', 'for', 'not', 'the']),
#  ('not', ['and', 'been', 'under', 'effective', 'for']),
#  ('want', ['Prime', 'Prime', 'at', 'of', 'women']),
#  ('to', ['.', 'see', 'than', 'be', '.']),
#  ('that', ['growers', 'for', 'we', 'to', 'Bill']),
#  ('in', ['to', 'action', 'very', 'be', 'I']),
#  ('.', ['given', 'the', 'what', 'Prime', 'them']),
#  ('they', ['to', 'they', 'of', 'has', 'the']),
#  ('need', ['have', 'be', 'at', 'growers', 'of']),
#  ('and', ['that', 'I', ',', '.', 'to']),
#  ('.', ['in', 'be', 'are', 'given', 'country']),
#  ('it', ['within', 'want', 'it', '.', 'Bill']),
#  ('does', ['one', 'job', 'as', '.', 'in']),
#  ('not', ['some', 'been', 'a', 'no', 'the']),
#  ('do', ['.', 'think', 'of', 'however', 'people']),
#  ('one', ['-', 'given', 'a', 'or', 'we']),
#  ('of', ['to', 'Bill', 'make', 'today', '.']),
#  ('for', ['job', 'it', '.', 'been', 'to']),
#  ('the', ['job', '$', 'in', 'in', 'very']),
#  ('people', ['to', '-', 'is', 'I', 'I']),
#  ('in', ['see', 'women', 'them', 'they', '.']),
#  ('our', ['this', 'look', 'this', '$', 'I']),
#  ('.', ['as', 'to', 'of', '.', '$']),
#  ('I', ['one', 'it', 'is', 'of', '-']),
#  ('think', ['job', 'on', 'in', 'action', 'we']),
#  ('that', ['are', 'which', 'and', '$', 'say']),
#  ('is', ['what', 'what', 'say', 'on', 'they']),
#  ('it', ['at', 'what', 'to', 'are', 'the']),
#  ('in', ['at', 'say', 'the', 'complex', 'what']),
#  ('a', ['in', 'and', 'on', 'have', 'have']),
#  ('very', ['to', 'women', 'they', 'of', '.']),
#  ('whole', ['as', 'are', 'given', 'however', 'people']),
#  ('as', ['-', 'Mr.', 'have', ',', 'that']),
#  ('to', ['it', 'has', 'of', 'has', 'at']),
#  ('what', ['is', 'for', ',', 'a', 'I']),
#  ('the', ['they', 'equity', 'a', 'within', 'which']),
#  ('are', ['most', ',', 'as', 'country', ',']),
#  ('and', ['we', '.', 'for', 'however', 'this']),
#  ('what', ['begin', 'a', 'does', '$', 'the']),
#  ('our', ['a', 'under', '.', 'to', 'that']),
#  ('to', ['see', 'action', 'by', 'should', 'growers']),
#  ('be', [',', 'have', 'been', 'let', ',']),
#  ('.', ['and', 'pretends', 'one', 'up', 'and']),
#  ('however', ['to', 'cost', 'need', 'most', ',']),
#  (',', ['women', '-', 'the', 'employment', 'most']),
#  ('there', ['Mr.', 'to', 'them', 'which', 'support']),
#  ('is', ['be', 'by', 'have', 'to', 'they']),
#  ('no', ['.', 'and', 'the', 'that', '.']),
#  ('action', ['let', 'to', 'let', 'will', 'support']),
#  ('.', ['this', 'some', 'that', 'there', 'Bill']),
#  ('we', ['our', 'for', 'it', '$', 'under']),
#  ('will', ['?', 'been', ',', 'I', 'the']),
#  ('have', [',', 'equity', 'the', 'for', 'at']),
#  ('given', ['one', 'do', 'that', 'up', 'been']),
#  ('up', ['.', 'pretends', 'Speaker', 'the', 'not']),
#  ('so', ['in', '.', '.', 'make', 'job']),
#  ('that', ['than', 'as', 'have', 'we', 'there']),
#  ('we', ['however', 'pretends', 'one', 'on', 'I']),
#  ('will', ['in', 'they', 'not', 'as', 'up']),
#  ('be', ['or', 'it', '-', 'for', 'the']),
#  ('than', [',', ',', '.', 'which', 'do']),
#  ('we', ['be', '.', '?', 'the', 'pretends']),
#  ('need', ['of', 'are', 'on', 'to', 'complex']),
#  ('to', ['today', 'look', 'have', 'they', 'I']),
#  ('be', ['action', 'that', 'the', 'to', '.']),
#  ('.', [',', 'need', 'been', 'in', 'make']),
#  ('under', ['be', 'on', 'very', 'by', 'be']),
#  ('this', ['complex', 'to', ',', 'it', 'been']),
#  ('Bill', ['at', 'as', 'the', 'however', 'given']),
#  ('it', ['does', 'see', 'that', 'we', 'however']),
#  ('would', ['very', 'and', 'this', 'action', 'they']),
#  ('be', ['the', 'women', ',', 'to', 'this']),
#  ('for', ['there', 'of', '$', 'up', 'need']),
#  ('a', ['in', 'programs', 'not', 'be', 'there']),
#  ('in', ['growers', 'most', 'very', 'have', 'who']),
#  ('a', ['that', ',', 'say', 'growers', 'complex']),
#  ('to', ['programs', 'the', 'Minister', '.', 'are']),
#  ('a', ['it', 'there', 'have', 'one', 'at']),
#  ('to', ['up', 'not', 'in', '.', 'Speaker']),
#  ('a', ['does', '$', 'women', 'begin', 'job']),
#  ('.', ['the', '.', 'up', 'as', ',']),
#  ('they', ['for', 'it', ',', 'not', ',']),
#  ('not', ['this', 'women', 'is', 'want', 'some']),
#  ('and', ['our', 'for', '-', 'in', 'is']),
#  ('no', ['is', 'in', 'up', 'however', 'we']),
#  ('one', ['is', 'say', '.', 'the', 'are']),
#  ('would', ['for', 'for', 'for', 'the', 'in']),
#  ('for', ['have', 'so', ',', 'we', '.']),
#  ('them', ['a', 'of', 'I', 'not', 'in']),
#  ('they', ['the', 'in', 'by', 'are', 'of']),
#  ('in', ['a', 'the', 'Speaker', '.', 'or']),
#  ('.', ['been', 'been', ',', 'Minister', 'the']),
#  ('as', ['will', 'to', 'I', 'on', 'of']),
#  ('are', ['programs', 'do', 'make', 'at', 'not']),
#  (',', ['this', 'we', '.', 'to', 'does']),
#  ('Mr.', ['in', 'the', 'whole', 'they', 'job']),
#  ('Speaker', ['Prime', 'want', 'of', '.', 'to']),
#  (',', ['for', ',', 'there', 'one', 'programs']),
#  ('under', ['of', 'for', 'Bill', 'make', '.']),
#  (',', ['in', 'to', 'we', 'that', 'of']),
#  ('they', ['think', 'Speaker', 'Speaker', 'is', 'people']),
#  ('make', ['they', 'is', 'let', 'not', 'it']),
#  ('at', ['.', 'the', 'employment', 'has', 'been']),
#  ('.', ['do', 'that', 'of', 'for', 'no']),
#  ('this', ['will', 'job', 'the', 'for', 'people']),
#  ('Bill', ['let', 'there', 'be', 'is', 'and']),
#  ('pretends', ['to', 'employment', 'so', 'and', '.']),
#  (',', ['Speaker', 'however', 'people', 'and', 'a']),
#  ('and', ['.', 'that', 'so', 'by', 'the']),
#  ('I', ['however', 'what', 'to', 'see', 'Speaker']),
#  ('say', ['however', 'the', 'equity', 'and', 'our']),
#  ('pretends', ['does', 'however', 'by', 'one', 'they']),
#  (',', ['I', 'of', 'to', 'by', 'effective']),
#  ('to', ['been', 'the', 'so', '-', 'of']),
#  ('do', ['the', 'the', 'very', 'however', 'would']),
#  ('employment', ['need', 'we', 'our', 'begin', 'what']),
#  ('equity', ['which', 'do', 'them', 'has', 'I']),
#  ('.', ['be', 'to', 'our', 'does', 'a']),
#  ('however', ['what', '.', 'to', 'them', 'effective']),
#  (',', ['has', 'Mr.', 'a', 'Bill', 'this']),
#  ('there', ['no', 'in', 'people', 'to', 'of']),
#  ('no', ['for', 'be', 'make', 'the', 'today']),
#  ('or', ['that', 'been', '.', 'and', 'they']),
#  ('of', ['by', 'say', '.', 'growers', 'that']),
#  ('that', ['have', 'support', 'in', 'under', 'are']),
#  ('people', ['need', 'a', 'not', '$', 'so']),
#  ('and', ['have', 'within', 'that', 'would', 'people']),
#  ('women', ['job', ',', 'does', ',', 'have']),
#  ('in', ['that', ',', 'make', 'by', 'a']),
#  ('the', ['say', 'to', 'for', 'the', 'our']),
#  ('.', ['?', 'our', 'want', 'to', 'not']),
#  ('they', ['a', 'very', 'growers', '.', 'for']),
#  ('want', ['to', 'some', 'the', 'no', 'in']),
#  ('to', ['what', 'Prime', 'of', 'we', 'a']),
#  ('see', ['this', 'and', 'complex', 'it', 'is']),
#  ('.', ['cost', 'have', 'has', 'to', ',']),
#  ('has', ['$', 'there', 'Bill', 'see', 'growers']),
#  ('been', ['.', '$', '.', ',', 'I']),
#  ('for', ['than', 'the', 'of', 'for', 'up']),
#  ('action', ['what', 'is', 'complex', 'Bill', 'for']),
#  ('in', ['need', 'are', 'by', 'employment', 'or']),
#  ('the', ['would', ',', ',', 'of', '.']),
#  ('of', ['be', 'a', 'has', 'that', 'Speaker']),
#  ('for', ['have', 'want', 'does', 'do', 'programs']),
#  ('some', ['-', 'we', 'to', 'to', 'we']),
#  ('and', ['programs', 'the', 'so', 'to', 'we']),
#  ('women', ['and', 'are', 'the', 'who', 'has']),
#  ('have', ['are', 'in', 'complex', 'some', 'to']),
#  ('to', ['Minister', 'to', 'growers', 'pretends', '.']),
#  ('for', ['is', 'have', 'some', 'within', 'want']),
#  ('it', ['our', 'the', 'a', 'growers', '.']),
#  ('.', ['be', 'very', 'be', 'and', '-']),
#  ('women', ['our', 'in', 'what', 'some', 'I']),
#  ('are', ['them', 'by', '.', 'and', 'to']),
#  ('to', ['equity', 'support', 'as', 'there', 'Bill']),
#  ('most', ['we', 'this', 'it', 'people', 'Prime']),
#  ('of', ['job', 'and', 'begin', 'support', 'the']),
#  ('the', ['Speaker', 'and', 'to', 'however', '.']),
#  ('job', ['need', 'has', ',', 'as', 'Bill']),
#  ('.', ['do', 'however', 'we', 'very', 'be']),
#  ('it', ['to', 'the', 'in', 'would', 'support']),
#  ('is', ['will', 'today', 'and', '.', 'the']),
#  ('very', ['do', 'are', 'the', 'for', 'in']),
#  ('that', ['which', 'our', 'not', 'as', 'people']),
#  ('we', ['who', 'on', 'however', 'women', 'equity']),
#  ('look', ['do', 'that', 'people', '.', 'the']),
#  ('at', ['the', 'growers', 'it', ',', 'given']),
#  ('employment', ['and', 'the', 'under', 'of', 'has']),
#  ('equity', ['people', 'and', 'need', 'growers', 'Prime']),
#  ('within', ['for', ',', '.', 'what', 'programs']),
#  ('the', ['we', 'of', 'very', 'Minister', 'the']),
#  ('job', ['some', 'Minister', 'action', 'begin', 'want']),
#  ('-', ['one', 'very', 'they', 'support', '.']),
#  ('programs', ['for', 'let', 'have', 'are', 'one']),
#  ('.', ['to', 'by', 'today', 'the', 'want']),
#  (',', ['.', 'in', 'be', 'who', 'is']),
#  ('Mr.', ['$', 'are', 'that', 'of', 'the']),
#  ('Speaker', ['growers', 'a', 'than', 'I', 'women']),
#  (',', ['a', 'are', 'to', 'however', 'no']),
#  ('we', ['let', 'that', 'it', 'our', 'we']),
#  ('the', ['equity', 'for', 'our', 'for', 'country']),
#  ('Prime', ['them', 'up', 'the', 'programs', 'for']),
#  ('Minister', ['.', 'which', 'let', 'we', 'are']),
#  ('Mr.', ['have', 'to', 'which', 'be', 'are']),
#  ('.', ['be', 'action', 'Speaker', 'equity', 'whole']),
#  ('what', ['today', 'make', 'very', 'no', 'they']),
#  ('will', ['however', 'Mr.', 'most', 'women', 'would']),
#  ('be', ['-', 'we', 'and', ',', 'or']),
#  ('the', ['growers', 'to', 'of', 'it', 'of']),
#  ('cost', ['want', 'in', 'is', 'to', 'public']),
#  ('of', [',', 'within', 'complex', 'of', 'Speaker']),
#  ('this', ['have', 'and', '.', '.', 'within']),
#  ('in', ['there', '.', '.', 'by', 'I']),
#  ('of', ['?', 'Minister', 'have', 'them', '?']),
#  ('as', ['cost', 'one', 'or', 'of', 'cost']),
#  ('it', ['are', 'the', 'growers', 'support', 'see']),
#  ('is', ['effective', 'need', 'as', 'a', 'been']),
#  ('to', ['be', 'been', 'to', 'have', 'are']),
#  ('?', ['is', 'a', 'want', 'programs', 'the']),
#  ('as', ['not', 'are', 'them', 'is', 'to']),
#  ('as', ['one', 'however', 'our', '$', 'want']),
#  ('the', ['and', 'do', 'people', 'that', 'under']),
#  ('growers', ['the', 'need', 'do', 'some', 'growers']),
#  ('begin', ['to', 'need', 'pretends', 'people', 'at']),
#  ('to', ['-', 'see', 'pretends', 'of', 'it']),
#  (',', ['within', 'employment', 'make', '.', 'today']),
#  ('who', ['the', 'as', 'have', 'in', 'and']),
#  ('the', ['.', 'is', 'make', 'Speaker', '.']),
#  ('growers', ['of', 'at', 'we', '.', ',']),
#  ('and', ['them', 'not', 'they', '.', 'would']),
#  ('support', ['most', 'or', 'want', ',', 'the']),
#  ('in', ['have', 'women', 'it', 'job', 'which']),
#  ('the', ['the', 'on', 'whole', 'have', 'our']),
#  ('begin', ['of', 'what', 'given', 'be', 'a']),
#  ('to', ['people', 'women', 'I', 'it', 'Prime']),
#  ('.', ['a', 'the', 'growers', 'are', 'for'])]

# %%
tokens = list(set(flat_subsampled_token_list))

#default dictionary key:id value:token
id2tokens = defaultdict(str)
                        
for i in range(len(tokens)):
    id2tokens[i] = tokens[i]
    
#default dictionary key:token value:id
tokens2id = defaultdict(int)

for ind in id2tokens:
    tokens2id[id2tokens[ind]] = ind
    
vocabulary_size = len(tokens2id)
print(vocabulary_size)
# Out:
# 84

# %%
#convert dataset to ids
pos_data = []
neg_data = []

for p in pos_context_pairs:
    pos_data.append((tokens2id[p[0]], tokens2id[p[1]]))
    
for n in neg_context_samples:
    
    word_id = tokens2id[n[0]]
    neg_samples = n[1]
    
    neg_ids = []
    
    for ns in neg_samples:
        neg_ids.append(tokens2id[ns])
        
    neg_data.append((word_id, neg_ids))

# %%
print(pos_data[0], pos_context_pairs[0], neg_context_samples[0], neg_data[0])
# Out:
# (41, 64) ('of', 'them') ('of', ['it', '?', 'have', 'the', 'and']) (41, [44, 47, 19, 10, 79])

# %%
pickle.dump(pos_data, open('pos_data.p', 'wb'))
pickle.dump(neg_data, open('neg_data.p', 'wb'))

# %%
pos_data = pickle.load(open('pos_data.p', 'rb'))
neg_data = pickle.load(open('neg_data.p', 'rb'))
